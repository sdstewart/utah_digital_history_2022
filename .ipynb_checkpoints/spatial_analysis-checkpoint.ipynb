# %% [markdown]
# # Spatial History
# Intro to Digital History, 4/4/2022
# Portions adapted from https://melaniewalsh.github.io/Intro-Cultural-Analytics/07-Mapping/01-Mapping.html

# %%
#!pip install geopy
#!pip install folium
#!pip install geopandas
# Out:
# Requirement already satisfied: geopy in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from geopy) (1.52)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/Spencer/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: folium in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: numpy in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.18.5)
# Requirement already satisfied: requests in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.27.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.2)
# Requirement already satisfied: branca>=0.3.0 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.0.12)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/Spencer/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: geopandas in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied: shapely>=1.6 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pandas>=0.24.0 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.0.5)
# Requirement already satisfied: fiona>=1.8 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.20)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.3.0-cp38-cp38-macosx_10_9_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 11.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.7 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: click>=4.0 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: setuptools in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (49.2.0.post20200714)
# Requirement already satisfied: munch in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: attrs>=17 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (19.3.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/Spencer/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (1.18.5)
# Installing collected packages: pyproj
#   Attempting uninstall: pyproj
#     Found existing installation: pyproj 1.9.6
#     Uninstalling pyproj-1.9.6:
#       Successfully uninstalled pyproj-1.9.6
# Successfully installed pyproj-3.3.0
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/Spencer/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
from geopy.geocoders import Nominatim
import folium

geolocator = Nominatim(user_agent="YOUR NAME's mapping app", timeout=2)

# %%
loc = "University of Utah"

location = geolocator.geocode(loc)

location
# Out:
# Location(University of Utah, 201, Presidents Circle, Salt Lake City, Salt Lake County, Utah, 84112, United States, (40.762813699999995, -111.83687191368261, 0.0))

# %%
print(location.address)
# Out:
# University of Utah, 201, Presidents Circle, Salt Lake City, Salt Lake County, Utah, 84112, United States

# %%
print(location.latitude, location.longitude)
# Out:
# 40.762813699999995 -111.83687191368261

# %%
print(f"Class: {location.raw['class']} \nType: {location.raw['type']}")
# Out:
# Class: amenity
# Type: university

# %%
utah_map = folium.Map(location=[location.latitude, location.longitude],
                     zoom_start=14)

folium.Marker(location=[location.latitude, location.longitude],
             popup="University of Utah").add_to(utah_map)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4547acdd5c1f4c57a2fa101247571d95%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4547acdd5c1f4c57a2fa101247571d95%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4547acdd5c1f4c57a2fa101247571d95%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4547acdd5c1f4c57a2fa101247571d95%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.762813699999995%2C%20-111.83687191368261%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
utah_map = folium.Map(location=[location.latitude, location.longitude],
                     zoom_start=10)

folium.CircleMarker(location=[location.latitude, location.longitude],
                    radius=10,
                    color = 'black',
                    fill_color = 'red',
                    fill_opacity = 0.6,
                    popup = "University of Utah").add_to(utah_map)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e7ce95118ed648b4a7a2034f0f3195c7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e7ce95118ed648b4a7a2034f0f3195c7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e7ce95118ed648b4a7a2034f0f3195c7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e7ce95118ed648b4a7a2034f0f3195c7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.762813699999995%2C%20-111.83687191368261%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
possible_locations = geolocator.geocode("University of Utah", exactly_one=False)

for location in possible_locations:
    print(location.address)
    print(location.latitude, location.longitude)
    print(f"Importance: {location.raw['importance']}")
# Out:
# University of Utah, 201, Presidents Circle, Salt Lake City, Salt Lake County, Utah, 84112, United States
# 40.762813699999995 -111.83687191368261
# Importance: 0.8557694184669417
# Department of Linguistics, University of Utah, 255, Central Campus Drive, Salt Lake City, Salt Lake County, Utah, 84112, United States
# 40.7634795 -111.8408017
# Importance: 0.31100000000000005
# Outdoor Adventures, Presidents Circle, Salt Lake City, Salt Lake County, Utah, 84112, United States
# 40.7655129 -111.838165
# Importance: 0.11100000000000002

# %% [markdown]
# # Where is Utah History?

# %% [markdown]
# Using Named Entity Recognition

# %%
#!pip install -U spacy
#!python -m spacy download en_core_web_sm
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
import pandas as pd

#Load UHQ data into a pandas dataframe
df = pd.read_excel("UHQ_FULL_EDITED.xlsx")

# %%
#Look at the first article in our database
text = df.text.tolist()[0]

#Run Named Entity Recognition on the text
document = nlp(text)

displacy.render(document[:500], style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     evening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 29, 1890
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 6:30 p.m.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , just past the corner of
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C Street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  and
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First Avenue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Salt Lake City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . It was almost dark; the sky was overcast and the weather portended
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of summer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frank C. Hall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thirty-eight year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  engineer by training currently employed as a barkeeper at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Mint Saloon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , strolled along in the company of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ann Hart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a widow of about his age. Hall was estranged from his wife and had custody of his
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  young children; they boarded with Hart at 277 C Street. The pair chatted amiably as they made their way toward
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brigham Street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# .</br>As they passed the corner of C and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  streets, a young woman stepped out from behind a tree, said something unintelligible, and fired a single shot, striking
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in the head and killing him instantly. Her name was
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amanda Olson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and she was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     twenty-two years old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  She was employed at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pearson’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  knitting factory and had recently moved with her parents to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     318 Sixth Avenue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Olsons
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’ new house was just around the corner from their previous residence at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     286 C Street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , which was across the street on the other end of the b

# %%
#Create a list of all location (GPE) entities in the text
location_list = []
for named_entity in document.ents:
    if named_entity.label_ == "GPE":
        location_list.append(named_entity.text.replace("’s", ""))

#Print our list
location_list
# Out:
# ['Salt Lake City',
#  'Salt Lake City',
#  'Salt Lake City',
#  'Utah',
#  'Salt Lake City',
#  'Amanda',
#  'Amanda',
#  'California',
#  'Salt Lake City',
#  'Park City',
#  'New York',
#  'Utah',
#  'Ogden',
#  'Washington',
#  'Utah',
#  'Utah',
#  'Utah',
#  'Michigan',
#  'Salt Lake City',
#  'Salt Lake City',
#  'Utah',
#  'Utah',
#  'New York',
#  'Chicago',
#  'Chicago',
#  'Herald',
#  'Russia']

# %% [markdown]
# ### Question: What are some potential problems that you see with this list?

# %%
#Is Amanda a place???
loc = "Amanda"

location = geolocator.geocode(loc)
location
# Out:
# Location(Amanda, Fairfield County, Ohio, United States, (39.649508, -82.7443367, 0.0))

# %%
#We can use the geolocator library to locate the latitude and longitude for each location. 

location_tally = Counter(location_list)

location_df = pd.DataFrame(location_tally.most_common(), columns=['location', 'count'])

loc_list = location_df.location.tolist()

lat = []
lon = []

for l in loc_list:
    temp_loc = geolocator.geocode(l)
    lat.append(temp_loc.latitude)
    lon.append(temp_loc.longitude)

location_df['lat'] = lat
location_df['lon'] = lon
location_df
# Out:
#           location  count        lat         lon
# 0   Salt Lake City      7  40.759620 -111.886798
# 1             Utah      7  39.422519 -111.714358
# 2           Amanda      2  39.649508  -82.744337
# 3         New York      2  40.712728  -74.006015
# 4          Chicago      2  41.875562  -87.624421
# 5       California      1  36.701463 -118.755997
# 6        Park City      1  40.646092 -111.497996
# 7            Ogden      1  41.223005 -111.973843
# 8       Washington      1  38.895037  -77.036543
# 9         Michigan      1  43.621195  -84.682435
# 10          Herald      1  37.966435  -88.181427
# 11          Russia      1  64.686314   97.745306

# %% [markdown]
# Note that this returns a single point in space. Are Utah, California, or even Russia one point on a map?

# %%
world_map = folium.Map(location=[42, -102], zoom_start=1)
location_df = location_df.dropna(subset=['lat', 'lon'])

lat = list(location_df["lat"])
long = list(location_df["lon"])
rad = list(location_df["count"])
name = list(location_df["location"])

for lt,ln,r,n in zip(lat,long,rad,name):
    folium.CircleMarker(location = [lt,ln],
                        popup=n,
                        radius = r).add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_47dbd8dd656140a68dfb9d1bc4acca67%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_47dbd8dd656140a68dfb9d1bc4acca67%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_47dbd8dd656140a68dfb9d1bc4acca67%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_47dbd8dd656140a68dfb9d1bc4acca67%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0%2C%20-102.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Using US Geological Survey Data

# %%
usgs_df = pd.read_csv("UTAH_USGS.csv")
len(usgs_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-e1517fe4dfb4> in <module>
# ----> 1 usgs_df = pd.read_csv("UTAH_USGS.csv")
#       2 len(usgs_df)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File UTAH_USGS.csv does not exist: 'UTAH_USGS.csv'

# %%
usgs_df[usgs_df.STATE_ALPHA == "UT"].FEATURE_CLASS.value_counts()
# Out:
# Valley             5730
# Populated Place    3618
# Spring             2554
# Stream             2545
# Summit             2351
# Locale             1926
# Church             1577
# Reservoir           961
# Building            906
# Lake                899
# School              870
# Flat                775
# Mine                704
# Canal               576
# Ridge               554
# Cemetery            531
# Park                455
# Basin               445
# Civil               403
# Dam                 384
# Gap                 310
# Post Office         259
# Bench               243
# Airport             221
# Arch                200
# Trail               188
# Pillar              179
# Cliff               177
# Well                131
# Range               113
# Tower               112
# Bend                106
# Census               98
# Area                 96
# Hospital             88
# Bay                  63
# Rapids               56
# Oilfield             52
# Slope                45
# Plain                44
# Bar                  38
# Bridge               37
# Reserve              34
# Cape                 33
# Woods                31
# Island               28
# Tunnel               27
# Falls                24
# Arroyo               18
# Military             18
# Forest               17
# Swamp                16
# Channel              12
# Gut                  10
# Beach                 9
# Crossing              6
# Crater                3
# Levee                 3
# Lava                  2
# Glacier               1
# Harbor                1
# Name: FEATURE_CLASS, dtype: int64

# %%
feature = "Populated Place"
ut_usgs_df = usgs_df[(usgs_df.STATE_ALPHA == "UT") & (usgs_df.FEATURE_CLASS == feature)]

# %%
ut_usgs_df[ut_usgs_df.FEATURE_NAME == "Salt Lake City"]
# Out:
#          FEATURE_ID    FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 1342331     1454997  Salt Lake City  Populated Place          UT
#
#          STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 1342331             49   Salt Lake            35.0         404539N
#
#         PRIM_LONG_DMS  PRIM_LAT_DEC  PRIM_LONG_DEC SOURCE_LAT_DMS  \
# 1342331      1115328W     40.760779    -111.891047            NaN
#
#         SOURCE_LONG_DMS  SOURCE_LAT_DEC  SOURCE_LONG_DEC  ELEV_IN_M  \
# 1342331             NaN             NaN              NaN     1300.0
#
#          ELEV_IN_FT              MAP_NAME DATE_CREATED DATE_EDITED
# 1342331      4265.0  Salt Lake City North   12/31/1979  05/11/2011

# %%
year_begin = 1928 #UHQ first year is 1928
year_end = 2021 #UHQ end year is 2021

#creating string containing all UHQ texts
df2 = df[(df['text'].notna()) & (df['year'] >= year_begin) & (df['year'] <= year_end)].reset_index()

full_uhq_texts = ' '.join([str(elem) for elem in df2.text.tolist()])

# %%
usgs_counts = []

for fn in ut_usgs_df.FEATURE_NAME.tolist():
    usgs_counts.append(full_uhq_texts.count(fn))
    
ut_usgs_df['FEATURE_COUNTS'] = usgs_counts
# Out:
# <ipython-input-22-7b0bfdab6c26>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ut_usgs_df['FEATURE_COUNTS'] = usgs_counts

# %%
len(usgs_counts), len(ut_usgs_df)
# Out:
# (3618, 3618)

# %%
ut_usgs_df
# Out:
#          FEATURE_ID           FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 347050       395885                  Utida  Populated Place          UT
# 1313673     1425039                Abraham  Populated Place          UT
# 1313684     1425050             Adamsville  Populated Place          UT
# 1313730     1425096               Altamont  Populated Place          UT
# 1313731     1425097                Altonah  Populated Place          UT
# ...             ...                    ...              ...         ...
# 2199708     2708039  Covered Bridge Canyon  Populated Place          UT
# 2260035     2783908             Interlaken  Populated Place          UT
# 2263734     2791542        Cedar Highlands  Populated Place          UT
# 2268987     2797924      Emigration Canyon  Populated Place          UT
# 2276439     2807120             East Basin  Populated Place          UT
#
#          STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 347050              49       Cache             5.0         415957N
# 1313673             49     Millard            27.0         392348N
# 1313684             49      Beaver             1.0         381530N
# 1313730             49    Duchesne            13.0         402134N
# 1313731             49    Duchesne            13.0         402405N
# ...                ...         ...             ...             ...
# 2199708             49        Utah            49.0         400209N
# 2260035             49     Wasatch            51.0         403230N
# 2263734             49        Iron            21.0         373815N
# 2268987             49   Salt Lake            35.0         404612N
# 2276439             49      Summit            43.0         404325N
#
#         PRIM_LONG_DMS  PRIM_LAT_DEC  ...  SOURCE_LAT_DMS SOURCE_LONG_DMS  \
# 347050       1115831W     41.999092  ...             NaN             NaN
# 1313673      1124305W     39.396620  ...             NaN             NaN
# 1313684      1124738W     38.258303  ...             NaN             NaN
# 1313730      1101711W     40.359398  ...             NaN             NaN
# 1313731      1101738W     40.401341  ...             NaN             NaN
# ...               ...           ...  ...             ...             ...
# 2199708      1113312W     40.035829  ...             NaN             NaN
# 2260035      1112823W     40.541664  ...             NaN             NaN
# 2263734      1130243W     37.637628  ...             NaN             NaN
# 2268987      1114535W     40.769979  ...             NaN             NaN
# 2276439      1112920W     40.723714  ...             NaN             NaN
#
#         SOURCE_LAT_DEC  SOURCE_LONG_DEC  ELEV_IN_M  ELEV_IN_FT  \
# 347050             NaN              NaN     1411.0      4629.0
# 1313673            NaN              NaN     1400.0      4593.0
# 1313684            NaN              NaN     1685.0      5528.0
# 1313730            NaN              NaN     1947.0      6388.0
# 1313731            NaN              NaN     2034.0      6673.0
# ...                ...              ...        ...         ...
# 2199708            NaN              NaN     1559.0      5115.0
# 2260035            NaN              NaN     1805.0      5922.0
# 2263734            NaN              NaN     2311.0      7582.0
# 2268987            NaN              NaN     1639.0      5377.0
# 2276439            NaN              NaN     1986.0      6516.0
#
#                   MAP_NAME DATE_CREATED DATE_EDITED FEATURE_COUNTS
# 347050             Trenton   12/31/1979         NaN              2
# 1313673         Sutherland   12/31/1979         NaN            335
# 1313684         Adamsville   12/31/1979         NaN              1
# 1313730           Altamont   12/31/1979  03/21/2008              0
# 1313731            Altonah   12/31/1979         NaN              1
# ...                    ...          ...         ...            ...
# 2199708  Spanish Fork Peak   11/04/2011  11/08/2011              0
# 2260035         Heber City   04/28/2016         NaN              0
# 2263734         Cedar City   05/17/2018  05/06/2021              0
# 2268987       Fort Douglas   03/04/2019         NaN             65
# 2276439     Park City East   05/08/2020         NaN              0
#
# [3618 rows x 21 columns]

# %% [markdown]
# Question: Do you notice any potential problems with the displayed data above? Note that "Abraham" appears in UHQ 335 times, but do you think all of these occurances refer to the location?

# %%
place_name = "Salt Lake City"
ut_usgs_df[ut_usgs_df.FEATURE_NAME == place_name]
# Out:
#          FEATURE_ID    FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 1342331     1454997  Salt Lake City  Populated Place          UT
#
#          STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 1342331             49   Salt Lake            35.0         404539N
#
#         PRIM_LONG_DMS  PRIM_LAT_DEC  ...  SOURCE_LAT_DMS SOURCE_LONG_DMS  \
# 1342331      1115328W     40.760779  ...             NaN             NaN
#
#         SOURCE_LAT_DEC  SOURCE_LONG_DEC  ELEV_IN_M  ELEV_IN_FT  \
# 1342331            NaN              NaN     1300.0      4265.0
#
#                      MAP_NAME DATE_CREATED DATE_EDITED FEATURE_COUNTS
# 1342331  Salt Lake City North   12/31/1979  05/11/2011           6049
#
# [1 rows x 21 columns]

# %%
utah_map = folium.Map(location=[39, -111], zoom_start=5)

min_number = 1

sub_df = ut_usgs_df[ut_usgs_df.FEATURE_COUNTS >= min_number]

lat = list(sub_df["PRIM_LAT_DEC"])
long = list(sub_df["PRIM_LONG_DEC"])
rad = list(sub_df["FEATURE_COUNTS"])
name = list(sub_df["FEATURE_NAME"])

for lt,ln,r,n in zip(lat,long,rad,name):
    folium.CircleMarker(location = [lt,ln],
                        popup=n,
                        tiles='Stamen Terrain',
                        radius = 1).add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_88053abc46034b9090930a8cf6d44ad9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_88053abc46034b9090930a8cf6d44ad9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_88053abc46034b9090930a8cf6d44ad9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_88053abc46034b9090930a8cf6d44ad9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%20-111.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# Try adjusting the "min_number" variable to see how your results change. Note that this approach is great at showing all of the places in Utah that are referenced at least 'n' number of times, but not great at showing volume. How much more likely is Salt Lake City or a place in Salt Lake County to appear than other locations in Utah? For that, we can turn to choropleth maps.

# %% [markdown]
# ## Choropleth Maps

# %%
#Import Libraries
import geopandas as gpd
import pandas as pd
import numpy as np
import folium
from folium.features import GeoJsonTooltip

#Read the geoJSON file using geopandas
geojson = gpd.read_file('spatial history/georef-united-states-of-america-county.geojson')
geojson=geojson[geojson['ste_name'] == "Utah"]

ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

folium.Choropleth(geo_data=geojson).add_to(ut_county_map)
ut_county_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_59f4947bc0594b679cda980f377c7743%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_59f4947bc0594b679cda980f377c7743%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_59f4947bc0594b679cda980f377c7743%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_59f4947bc0594b679cda980f377c7743%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.5%2C%20-111.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
min_number = 1

sub_df = ut_usgs_df[ut_usgs_df.FEATURE_COUNTS >= min_number]

county_counts = pd.DataFrame(sub_df['COUNTY_NAME'].value_counts().reset_index())
county_counts.columns = ['county_name', 'loc_count']
total_count = []
for county in county_counts.county_name.tolist():
    #sub_df = ut_usgs_df[ut_usgs_df.COUNTY_NAME == county]
    total_count.append(sub_df[sub_df.COUNTY_NAME == county]['FEATURE_COUNTS'].sum())

county_counts['total_count'] = total_count

county_counts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-3d5a38e15078> in <module>
#       1 min_number = 1
#       2
# ----> 3 sub_df = ut_usgs_df[ut_usgs_df.FEATURE_COUNTS >= min_number]
#       4
#       5 county_counts = pd.DataFrame(sub_df['COUNTY_NAME'].value_counts().reset_index())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'FEATURE_COUNTS'

# %%
df_final = geojson.merge(county_counts, left_on="coty_name", right_on="county_name", how="outer") 
df_final = df_final[~df_final['geometry'].isna()]
df_final
# Out:
#    coty_code coty_gnis_code     coty_name_long ste_name coty_type  year  \
# 0      49037       01448032    San Juan County     Utah    county  2020
# 1      49043       01448035      Summit County     Utah    county  2020
# 2      49041       01448034      Sevier County     Utah    county  2020
# 3      49051       01448039     Wasatch County     Utah    county  2020
# 4      49021       01448025        Iron County     Utah    county  2020
# 5      49017       01448023    Garfield County     Utah    county  2020
# 6      49011       01448020       Davis County     Utah    county  2020
# 7      49009       01448019     Daggett County     Utah    county  2020
# 8      49029       01448028      Morgan County     Utah    county  2020
# 9      49035       01448031   Salt Lake County     Utah    county  2020
# 10     49057       01448042       Weber County     Utah    county  2020
# 11     49013       01448021    Duchesne County     Utah    county  2020
# 12     49031       01448029       Piute County     Utah    county  2020
# 13     49033       01448030        Rich County     Utah    county  2020
# 14     49039       01448033     Sanpete County     Utah    county  2020
# 15     49023       01455158        Juab County     Utah    county  2020
# 16     49005       01448017       Cache County     Utah    county  2020
# 17     49007       01448018      Carbon County     Utah    county  2020
# 18     49053       01448040  Washington County     Utah    county  2020
# 19     49003       01455966   Box Elder County     Utah    county  2020
# 20     49015       01448022       Emery County     Utah    county  2020
# 21     49001       01448015      Beaver County     Utah    county  2020
# 22     49019       01448024       Grand County     Utah    county  2020
# 23     49047       01448037      Uintah County     Utah    county  2020
# 24     49027       01448027     Millard County     Utah    county  2020
# 25     49045       01448036      Tooele County     Utah    county  2020
# 26     49055       01448041       Wayne County     Utah    county  2020
# 27     49049       01448038        Utah County     Utah    county  2020
# 28     49025       01448026        Kane County     Utah    county  2020
#
#    coty_area_code ste_code coty_fp_code   coty_name  \
# 0             USA       49          037    San Juan
# 1             USA       49          043      Summit
# 2             USA       49          041      Sevier
# 3             USA       49          051     Wasatch
# 4             USA       49          021        Iron
# 5             USA       49          017    Garfield
# 6             USA       49          011       Davis
# 7             USA       49          009     Daggett
# 8             USA       49          029      Morgan
# 9             USA       49          035   Salt Lake
# 10            USA       49          057       Weber
# 11            USA       49          013    Duchesne
# 12            USA       49          031       Piute
# 13            USA       49          033        Rich
# 14            USA       49          039     Sanpete
# 15            USA       49          023        Juab
# 16            USA       49          005       Cache
# 17            USA       49          007      Carbon
# 18            USA       49          053  Washington
# 19            USA       49          003   Box Elder
# 20            USA       49          015       Emery
# 21            USA       49          001      Beaver
# 22            USA       49          019       Grand
# 23            USA       49          047      Uintah
# 24            USA       49          027     Millard
# 25            USA       49          045      Tooele
# 26            USA       49          055       Wayne
# 27            USA       49          049        Utah
# 28            USA       49          025        Kane
#
#                                                                                                                                                                                                                                                                                                                                                                                                            geometry  \
# 0   POLYGON ((-109.92799 38.15188, -109.92719 38.14796, -109.92937 38.13992, -109.93323 38.13630, -109.94366 38.13516, -109.95677 38.12945, -109.96269 38.11937, -109.96364 38.11433, -109.96950 38.11198, -109.97793 38.11010, -109.98214 38.10679, -109.98504 38.10178, -109.99250 38.09995, -109.99595 38.10052, -110.00102 38.10663, -110.00576 38.10955, -110.00949 38.10966, -110.01668 38.10613, -110.026...
# 1   POLYGON ((-111.26497 41.14404, -111.27467 41.14257, -111.28972 41.14326, -111.29444 41.13913, -111.30009 41.13717, -111.30162 41.13442, -111.30701 41.13093, -111.31020 41.13049, -111.31846 41.13244, -111.32412 41.13745, -111.33239 41.13810, -111.33787 41.13304, -111.34096 41.13282, -111.34579 41.12872, -111.34886 41.12997, -111.36037 41.12919, -111.36660 41.13002, -111.36868 41.12201, -111.367...
ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

map_variable = 'total_count' #possible variables: 'loc_count' & 'total_count'

folium.Choropleth(
            geo_data=geojson,
            data=df_final,
            columns=['coty_code', map_variable],  #Here we tell folium to get the county fips and plot new_cases_7days metric for each county
            key_on='feature.properties.coty_code', #Here we grab the geometries/county boundaries from the geojson file using the key 'coty_code' which is the same as county fips
            #threshold_scale=(df_final[map_variable].quantile((0, 0.2, 0.4, 0.6, 0.8, 1))).tolist(), #we can create our own custom scale if we like.
            fill_color='YlOrRd',
            nan_fill_color="White", #Use white color if there is no data available for the county
            fill_opacity=0.7,
            line_opacity=0.2,
            legend_name='', #title of the legend
            highlight=True,
            line_color='black').add_to(ut_county_map)

ut_county_map
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-88-cd7ba5c6e7ee> in <module>
#       3 map_variable = 'total_count' #possible variables: 'loc_count' & 'total_count'
#       4
# ----> 5 folium.Choropleth(
#       6             geo_data=geojson,
#       7             data=df_final,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1287                 smooth_factor=smooth_factor)
#    1288         else:
# -> 1289             self.geojson = GeoJson(
#    1290                 geo_data,
#    1291                 style_function=style_function,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     497         self.marker = marker
#     498
# --> 499         self.data = self.process_data(data)
#     500
#     501         if self.style or self.highlight:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in process_data(self, data)
#     539             self.embed = True
#     540             if hasattr(data, 'to_crs'):
# --> 541                 data = data.to_crs('EPSG:4326')
#     542             return json.loads(json.dumps(data.__geo_interface__))
#     543         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py in to_crs(self, crs, epsg, inplace)
#    1245         else:
#    1246             df = self.copy()
# -> 1247         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1248         df.geometry = geom
#    1249         df.crs = geom.crs
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geoseries.py in to_crs(self, crs, epsg)
#    1026         """
#    1027         return GeoSeries(
# -> 1028             self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1029         )
#    1030
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/array.py in to_crs(self, crs, epsg)
#     783             )
#     784         if crs is not None:
# --> 785             crs = CRS.from_user_input(crs)
#     786         elif epsg is not None:
#     787             crs = CRS.from_epsg(epsg)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py in from_user_input(value, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py in __init__(self, projparams, **kwargs)
#
# pyproj/_crs.pyx in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: EPSG:4326: (Internal Proj Error: proj_create: no database context specified)

# %% [markdown]
# # Combining USGS and NER

# %%
import pandas as pd

#Load UHQ data into a pandas dataframe
df = pd.read_excel("UHQ_FULL_EDITED.xlsx")

year_begin = 1928 #UHQ first year is 1928
year_end = 2021 #UHQ end year is 2021

#creating string containing all UHQ texts
df2 = df[(df['text'].notna()) & (df['year'] >= year_begin) & (df['year'] <= year_end)].reset_index()


#Look at the first article in our database
texts = df2.text.tolist()

places = []
#Run Named Entity Recognition on the text
for t in texts:
    document = nlp(t)
    for named_entity in document.ents:
        if named_entity.label_ == "GPE":
            places.append(named_entity.text.replace("’s", ""))
len(places)
# Out:
# 94236

# %%
places_tally = Counter(places)
places_df = pd.DataFrame(places_tally.most_common(), columns=['place', 'count'])
places_df.to_csv("ner_places.csv")

# %%
places_df = pd.read_excel('spatial history/ner_places.xlsx')
places_df[:50]
# Out:
#                 place    count
# 0                Utah  20358.0
# 1      Salt Lake City   5323.0
# 2          California   2243.0
# 3   the United States   1985.0
# 4            Colorado   1971.0
# 5               Ogden   1615.0
# 6           Salt Lake   1373.0
# 7          Washington   1230.0
# 8             America   1179.0
# 9              Nevada    968.0
# 10         New Mexico    915.0
# 11           New York    899.0
# 12              Idaho    836.0
# 13            Arizona    831.0
# 14              Provo    816.0
# 15            Wyoming    711.0
# 16               U.S.    708.0
# 17           Missouri    652.0
# 18       Saint George    625.0
# 19      San Francisco    617.0
# 20            England    571.0
# 21             Denver    506.0
# 22           Illinois    494.0
# 23             Mexico    450.0
# 24          Park City    430.0
# 25      Carbon County    408.0
# 26             Oregon    403.0
# 27            Chicago    398.0
# 28            Fremont    386.0
# 29              Smoot    378.0
# 30      United States    370.0
# 31            Germany    370.0
# 32            Montana    346.0
# 33              Logan    340.0
# 34            Corinne    337.0
# 35         Cedar City    330.0
# 36          St. Louis    315.0
# 37               Ohio    312.0
# 38            Bingham    305.0
# 39           San Juan    291.0
# 40              Texas    290.0
# 41             France    288.0
# 42        Los Angeles    282.0
# 43       Fort Douglas    267.0
# 44               Iowa    258.0
# 45       Brigham City    258.0
# 46             Kansas    258.0
# 47          Utah Lake    257.0
# 48       Fort Bridger    251.0
# 49   Salt Lake County    234.0

# %%
usgs_df = pd.read_csv("spatial history/UTAH_USGS.csv")
feature = "Populated Place"
ut_usgs_df = usgs_df[(usgs_df.STATE_ALPHA == "UT") & (usgs_df.FEATURE_CLASS == feature)]


place_match = []
place_miss = []

for p in places_df.place.tolist():
    if p in ut_usgs_df.FEATURE_NAME.tolist():
        place_match.append(p)
    else:
        place_miss.append(p)

# %%
utah_df = ut_usgs_df.merge(places_df, left_on="FEATURE_NAME", right_on="place", how="inner")
utah_df
# Out:
#      Unnamed: 0  FEATURE_ID          FEATURE_NAME    FEATURE_CLASS  \
# 0       1313684     1425050            Adamsville  Populated Place
# 1       1313731     1425097               Altonah  Populated Place
# 2       1313835     1425202                Atwood  Populated Place
# 3       1314060     1425433                Benson  Populated Place
# 4       1314332     1425709            Black Rock  Populated Place
# 5       1314464     1425842                 Bluff  Populated Place
# 6       1314487     1425865               Bonanza  Populated Place
# 7       1314887     1426269            Caineville  Populated Place
# 8       1314961     1426344           Cannonville  Populated Place
# 9       1314968     1426351           Carbonville  Populated Place
# 10      1314997     1426380           Castle Dale  Populated Place
# 11      1315058     1426441            Cedar City  Populated Place
# 12      1315121     1426506           Centerfield  Populated Place
# 13      1339244     1451674           Centerfield  Populated Place
# 14      1315153     1426539            Charleston  Populated Place
# 15      1315282     1426671             Clarkston  Populated Place
# 16      1315286     1426675               Clawson  Populated Place
# 17      1315322     1426712             Cleveland  Populated Place
# 18      1315335     1426725               Clinton  Populated Place
# 19      1325681     1437526               Clinton  Populated Place
# 20      1315380     1426770             Coalville  Populated Place
# 21      1315425     1426815              Columbia  Populated Place
# 22      1315932     1427334                 Delta  Populated Place
# 23      1315941     1427343               Deseret  Populated Place
# 24      1339259     1451689               Deseret  Populated Place
# 25      1341160     1453732               Deseret  Populated Place
# 26      1316018     1427422              Dividend  Populated Place
# 27      1316063     1427468             Dragerton  Populated Place
# 28      1316068     1427473                Draper  Populated Place
# 29      1316196     1427601              Duchesne  Populated Place
# 30      1316303     1427710        East Millcreek  Populated Place
# 31      1316329     1427737              Eastland  Populated Place
# 32      1316332     1427740                  Echo  Populated Place
# 33      1316338     1427746                  Eden  Populated Place
# 164     1325647     1437492                  Avon  Populated Place
# 165     1326453     1438313                  Avon  Populated Place
# 166     1325651     1437496                Barnes  Populated Place
# 167     1325659     1437504           Bloomington  Populated Place
# 168     1325664     1437509                Borden  Populated Place
# 169     1325666     1437511              Bradford  Populated Place
# 170     1325671     1437516                Callao  Populated Place
# 171     1325672     1437517           Castle Rock  Populated Place
# 172     1325673     1437518                 Cedar  Populated Place
# 173     1325677     1437522                 Cisco  Populated Place
# 174     1325679     1437524            Clear Lake  Populated Place
# 175     1325680     1437525               Clifton  Populated Place
# 176     1325683     1437528                Clover  Populated Place
# 177     1325688     1437533               Cornish  Populated Place
# 178     1325696     1437541                Dalton  Populated Place
# 179     1339610     1452149                Dalton  Populated Place
# 180     1325702     1437547                Dragon  Populated Place
# 181     1325705     1437550                  Elba  Populated Place
# 182     1325706     1437551                 Elgin  Populated Place
# 183     1325707     1437552                 Emory  Populated Place
# 184     1325709     1437554                 Enoch  Populated Place
# 185     1325714     1437559                 Faust  Populated Place
# 186     1325718     1437563                Frisco  Populated Place
# 187     1325719     1437564             Fruitland  Populated Place
# 188     1325720     1437565              Garfield  Populated Place
# 189     1325722     1437567            Georgetown  Populated Place
# 190     1339802     1452348            Georgetown  Populated Place
# 191     1325725     1437570               Grafton  Populated Place
# 192     1325727     1437572             Greenwich  Populated Place
# 193     1325730     1437575                Grover  Populated Place
# 194     1325731     1437576               Gunlock  Populated Place
# 195     1325736     1437581               Harding  Populated Place
# 196     1325738     1437583            Harrisburg  Populated Place
# 197     1325740     1437585                Hayden  Populated Place
# 198     1325743     1437588             Hillsdale  Populated Place
# 199     1339294     1451724             Hillsdale  Populated Place
# 200     1341170     1453742             Hillsdale  Populated Place
# 201     1325745     1437590           Homansville  Populated Place
# 202     1325746     1437591                Howell  Populated Place
# 203     1325747     1437592                Ibapah  Populated Place
# 204     1325748     1437593          Independence  Populated Place
# 205     2078508     2547779          Independence  Populated Place
# 206     1325749     1437594                  Ioka  Populated Place
# 207     1325751     1437596          Iron Springs  Populated Place
# 208     1325752     1437597               Jericho  Populated Place
# 209     1325754     1437599                  Juab  Populated Place
# 210     1325755     1437600               Keetley  Populated Place
# 211     1325758     1437603                Kelton  Populated Place
# 212     1325761     1437606           Knightville  Populated Place
# 213     1325762     1437607                Knolls  Populated Place
# 214     1325767     1437612              Lakeside  Populated Place
# 215     1339312     1451742              Lakeside  Populated Place
# 216     1325768     1437613                Lakota  Populated Place
# 217     1325774     1437619                Latuda  Populated Place
# 218     1325775     1437620              Lawrence  Populated Place
# 219     1325783     1437628                  Mack  Populated Place
# 220     1325784     1437629                Madsen  Populated Place
# 221     1339322     1451752                Madsen  Populated Place
# 222     1325788     1437633              Marshall  Populated Place
# 223     1325791     1437636             Middleton  Populated Place
# 224     1325794     1437639              Mohrland  Populated Place
# 225     1325798     1437643                Mosida  Populated Place
# 226     1325800     1437645            Mound City  Populated Place
# 227     1325802     1437647               Murdock  Populated Place
# 228     1341459     1454046               Murdock  Populated Place
# 294     1329729     1441617           Harrisville  Populated Place
# 295     1329921     1441810              Holladay  Populated Place
# 296     1330073     1441964             Hyde Park  Populated Place
# 297     1330077     1441968                 Hyrum  Populated Place
# 298     1330147     1442038        Indian Village  Populated Place
# 299     1339838     1452384        Indian Village  Populated Place
# 300     1340161     1452713        Indian Village  Populated Place
# 301     1330148     1442039             Indianola  Populated Place
# 302     1330169     1442060               Ironton  Populated Place
# 303     1330241     1442132             Jerusalem  Populated Place
# 304     1330332     1442224                Joseph  Populated Place
# 305     1330373     1442266                 Kamas  Populated Place
# 306     1330383     1442277                Kanosh  Populated Place
# 307     1330391     1442285             Kaysville  Populated Place
# 308     1330440     1442334              Kingston  Populated Place
# 309     1330482     1442376                La Sal  Populated Place
# 310     1330564     1442459                Layton  Populated Place
# 311     1330585     1442480                 Leeds  Populated Place
# 312     1330658     1442553                  Lehi  Populated Place
# 313     1330661     1442556                Leland  Populated Place
# 314     1330669     1442564                 Levan  Populated Place
# 315     1330673     1442568                 Lewis  Populated Place
# 316     1330678     1442573              Lewiston  Populated Place
# 317     1330924     1442822                   Loa  Populated Place
# 318     1330951     1442849                 Logan  Populated Place
# 319     1331038     1442937  Long Valley Junction  Populated Place
# 320     1331150     1443051                  Lynn  Populated Place
# 321     1331223     1443126                Manila  Populated Place
# 322     1331233     1443136                 Manti  Populated Place
# 323     1331286     1443189              Mapleton  Populated Place
# 324     1331317     1443220             Marysvale  Populated Place
# 325     1331334     1443237              Mayfield  Populated Place
# 326     1340292     1452844              Mayfield  Populated Place
# 327     1331480     1443385               Milburn  Populated Place
# 328     1331538     1443443             Mill Fork  Populated Place
# 329     1331591     1443496             Millville  Populated Place
# 330     1331643     1443548                  Mona  Populated Place
# 331     1331651     1443556                Monroe  Populated Place
# 332     1331663     1443568            Monticello  Populated Place
# 333     1331724     1443630        Mount Sterling  Populated Place
# 334     1331836     1443742                Murray  Populated Place
# 335     1331887     1443793                 Nephi  Populated Place
# 336     1331902     1443808           New Harmony  Populated Place
# 337     1331906     1443812             Newcastle  Populated Place
# 338     1331911     1443817                Nibley  Populated Place
# 339     1331912     1443818                Nibley  Populated Place
# 340     1331963     1443869           North Creek  Populated Place
# 341     1332049     1443956           North Logan  Populated Place
# 342     1332054     1443962           North Ogden  Populated Place
# 343     1332104     1444013              Oak City  Populated Place
# 344     1332105     1444014             Oak Creek  Populated Place
# 345     1332134     1444043                Oakley  Populated Place
# 346     1341631     1454224                Oakley  Populated Place
# 347     1332140     1444049                 Ogden  Populated Place
# 348     1332201     1444110                  Orem  Populated Place
# 349     1332258     1444167               Palmyra  Populated Place
# 350     1332261     1444170             Panguitch  Populated Place
# 351     1332295     1444206             Park City  Populated Place
# 352     1332313     1444224               Parowan  Populated Place
# 353     1332341     1444252                Payson  Populated Place
# 354     1332371     1444282                  Peoa  Populated Place
# 355     1332498     1444412           Pine Valley  Populated Place
# 356     1332520     1444434               Pintura  Populated Place
# 357     1332550     1444464             Pittsburg  Populated Place
# 358     1332557     1444471            Plain City  Populated Place
# 359     1332565     1444479        Pleasant Grove  Populated Place
# 360     1332571     1444485         Pleasant View  Populated Place
# 361     1332572     1444486         Pleasant View  Populated Place
# 362     1339025     1451452         Pleasant View  Populated Place
# 363     1332574     1444488              Plymouth  Populated Place
# 364     1332741     1444657            Providence  Populated Place
# 365     1332745     1444661                 Provo  Populated Place
# 366     1332925     1444843               Redmond  Populated Place
# 367     1332971     1444889             Richfield  Populated Place
# 368     1332974     1444892              Richmond  Populated Place
# 369     1333073     1444991         River Heights  Populated Place
# 370     1333332     1445252        Sahara Village  Populated Place
# 371     1333342     1445262                 Salem  Populated Place
# 372     1333349     1445269                Salina  Populated Place
# 373     1333409     1445329             Santaquin  Populated Place
# 374     1333456     1445376                Scipio  Populated Place
# 375     1333460     1445380              Scofield  Populated Place
# 376     1333672     1445595           Silver Fork  Populated Place
# 377     1333679     1445602           Silver Reef  Populated Place
# 378     1333744     1445667           Slaterville  Populated Place
# 379     1333786     1445709            Smithfield  Populated Place
# 380     1339493     1451926            Smithfield  Populated Place
# 381     1334010     1445935           South Weber  Populated Place
# 382     1334020     1445945          Spanish Fork  Populated Place
# 383     1334066     1445992           Spring City  Populated Place
# 384     1334125     1446051           Spring Lake  Populated Place
# 385     1334131     1446057           Springville  Populated Place
# 386     1334282     1446208           Sugar House  Populated Place
# 387     1334432     1446361              Teasdale  Populated Place
# 388     1334722     1446655           Toquerville  Populated Place
# 389     1334725     1446658                Torrey  Populated Place
# 390     1334728     1446661              Townsend  Populated Place
# 391     1334789     1446722                Tropic  Populated Place
# 392     1334901     1446835                Uintah  Populated Place
# 393     1334967     1446903              Valencia  Populated Place
# 394     1334984     1446921                Venice  Populated Place
# 395     1334995     1446932                Vernon  Populated Place
# 396     1335006     1446943           Vivian Park  Populated Place
# 397     1335017     1446954                 Wales  Populated Place
# 398     1335030     1446968             Wallsburg  Populated Place
# 399     1335057     1446995                Warren  Populated Place
# 400     1335078     1447016              Washakie  Populated Place
# 401     1335081     1447019            Washington  Populated Place
# 402     1335088     1447026    Washington Terrace  Populated Place
# 403     1335142     1447080                Wattis  Populated Place
# 404     1335165     1447103            Wellsville  Populated Place
# 405     1335226     1447164           West Layton  Populated Place
# 406     1335249     1447187            West Weber  Populated Place
# 407     1335433     1447372               Willard  Populated Place
# 408     1340123     1452673               Willard  Populated Place
# 409     1336409     1448413           Forest Dale  Populated Place
# 410     1336466     1448472              Highland  Populated Place
# 411     1339167     1451596              Highland  Populated Place
# 412     1337009     1449026      South Cottonwood  Populated Place
# 413     1337980     1450235                Austin  Populated Place
# 414     1338022     1450284         Castle Valley  Populated Place
# 415     1338109     1450387               Hildale  Populated Place
# 416     1338143     1450429                Mendon  Populated Place
# 417     1338725     1451119               Mammoth  Populated Place
# 418     1338803     1451217             Consumers  Populated Place
# 419     1339037     1451465                 White  Populated Place
# 420     1339077     1451505                Parker  Populated Place
# 421     1339094     1451522                  Moss  Populated Place
# 422     1339103     1451531                Athens  Populated Place
# 423     1339153     1451582             El Dorado  Populated Place
# 489     1340612     1453168           Burch Creek  Populated Place
# 490     1340715     1453271           Cedar Ridge  Populated Place
# 491     1340738     1453294                Allred  Populated Place
# 492     1340791     1453350              Shamrock  Populated Place
# 493     1340811     1453372               Esquire  Populated Place
# 494     1340858     1453421            North Park  Populated Place
# 495     1341125     1453697            North Park  Populated Place
# 496     1340874     1453437               Terrace  Populated Place
# 497     1340902     1453466     Arlington Heights  Populated Place
# 498     1340955     1453520                 Irene  Populated Place
# 499     1341049     1453618             Wakefield  Populated Place
# 500     1341063     1453632          Garden Grove  Populated Place
# 501     1341065     1453634             Highlands  Populated Place
# 502     1341109     1453681              Chandler  Populated Place
# 503     1341122     1453694                 Major  Populated Place
# 504     1341171     1453743              Holbrook  Populated Place
# 505     1341192     1453768              Sunshine  Populated Place
# 506     1341194     1453770                 Villa  Populated Place
# 507     1341256     1453836           Browns Park  Populated Place
# 508     1341278     1453861              Pleasant  Populated Place
# 509     1341307     1453890              Lakeland  Populated Place
# 510     1341319     1453902           Quail Creek  Populated Place
# 511     1341357     1453941                  King  Populated Place
# 512     1341427     1454011         Mountain View  Populated Place
# 513     1341458     1454045                Lester  Populated Place
# 514     1341489     1454078               Newport  Populated Place
# 515     1341552     1454141                Thomas  Populated Place
# 516     1341597     1454190              Colorado  Populated Place
# 517     1341610     1454203                Hanson  Populated Place
# 518     1341612     1454205           Hot Springs  Populated Place
# 519     1341622     1454215               Marsden  Populated Place
# 520     1341636     1454230          Rock Springs  Populated Place
# 521     1341641     1454235              Superior  Populated Place
# 522     1341654     1454248         Williamsburgh  Populated Place
# 523     1341693     1454287                Blaine  Populated Place
# 524     1341695     1454289               Bullock  Populated Place
# 525     1341698     1454292                 Butte  Populated Place
# 526     1341703     1454297              Cummings  Populated Place
# 527     1342331     1454997        Salt Lake City  Populated Place
# 528     1342407     1455093               Diamond  Populated Place
# 529     1342410     1455096                Milton  Populated Place
# 530     1342411     1455097                 Paria  Populated Place
# 531     1342412     1455098          Saint George  Populated Place
# 532     1343095     1455857             Elk Ridge  Populated Place
# 533     1343109     1455872                Daniel  Populated Place
# 534     1343111     1455874      East Carbon City  Populated Place
# 535     1343115     1455878            Heber City  Populated Place
# 536     1343141     1455905            Sandy City  Populated Place
# 537     1557320     1681817               Portage  Populated Place
# 538     1574708     1699809           Rush Valley  Populated Place
# 539     1715141     1852443                Garden  Populated Place
# 540     1727991     1867579             Millcreek  Populated Place
# 541     2268987     2797924     Emigration Canyon  Populated Place
#
#     STATE_ALPHA  STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 0            UT             49      Beaver             1.0         381530N
# 1            UT             49    Duchesne            13.0         402405N
# 2            UT             49   Salt Lake            35.0         403758N
# 3            UT             49       Cache             5.0         414715N
# 4            UT             49     Millard            27.0         384256N
# 5            UT             49    San Juan            37.0         371704N
# 6            UT             49      Uintah            47.0         400116N
# 7            UT             49       Wayne            55.0         381959N
# 8            UT             49    Garfield            17.0         373401N
# 9            UT             49      Carbon             7.0         393712N
# 10           UT             49       Emery            15.0         391244N
# 11           UT             49        Iron            21.0         374039N
# 82           UT             49        Rich            33.0         414932N
# 83           UT             49     Millard            27.0         393205N
# 84           UT             49      Tooele            45.0         403354N
# 85           UT             49        Utah            49.0         401644N
# 86           UT             49      Morgan            29.0         410221N
# 87           UT             49     Millard            27.0         393109N
# 88           UT             49   Salt Lake            35.0         404233N
# 89           UT             49       Weber            57.0         411441N
# 90           UT             49     Millard            27.0         385309N
# 91           UT             49   Salt Lake            35.0         403640N
# 92           UT             49     Wasatch            51.0         403044N
# 93           UT             49      Beaver             1.0         382349N
# 94           UT             49      Beaver             1.0         381251N
# 95           UT             49       Grand            19.0         383424N
# 96           UT             49        Iron            21.0         374756N
# 97           UT             49    San Juan            37.0         371612N
# 98           UT             49      Morgan            29.0         410210N
# 99           UT             49     Sanpete            39.0         393130N
# 100          UT             49     Sanpete            39.0         393249N
# 101          UT             49    Duchesne            13.0         401140N
# 102          UT             49      Uintah            47.0         402537N
# 103          UT             49       Cache             5.0         415146N
# 104          UT             49   Salt Lake            35.0         404133N
# 105          UT             49     Millard            27.0         391738N
# 106          UT             49      Tooele            45.0         402210N
# 107          UT             49       Emery            15.0         391338N
# 108          UT             49        Kane            25.0         371633N
# 109          UT             49      Uintah            47.0         400521N
# 110          UT             49        Iron            21.0         375309N
# 111          UT             49   Box Elder             3.0         414903N
# 112          UT             49      Carbon             7.0         393558N
# 113          UT             49      Uintah            47.0         401358N
# 114          UT             49        Rich            33.0         413957N
# 115          UT             49   Box Elder             3.0         414720N
# 116          UT             49       Cache             5.0         414752N
# 117          UT             49   Salt Lake            35.0         404357N
# 118          UT             49   Salt Lake            35.0         404311N
# 119          UT             49   Salt Lake            35.0         404700N
# 120          UT             49  Washington            53.0         370940N
# 121          UT             49    Duchesne            13.0         401758N
# 122          UT             49  Washington            53.0         370759N
# 123          UT             49   Box Elder             3.0         415756N
# 124          UT             49      Carbon             7.0         393934N
# 125          UT             49   Salt Lake            35.0         404602N
# 126          UT             49  Washington            53.0         371120N
# ...
# 99                 Moroni     9.0
# 100        Mount Pleasant    15.0
# 101                 Myton    38.0
# 102                Naples     3.0
# 103                Newton    39.0
# 104                Newton    39.0
# 105                 Oasis     1.0
# 106                 Ophir    38.0
# 107           Orangeville    19.0
# 108            Orderville     8.0
# 109                 Ouray    13.0
# 110             Paragonah     9.0
# 111           Park Valley     4.0
# 112                 Price    98.0
# 113              Randlett     5.0
# 114              Randolph     5.0
# 115             Riverside     1.0
# 116             Riverside     1.0
# 117             Riverside     1.0
# 118             Riverside     1.0
# 119             Riverside     1.0
# 120             Rockville    51.0
# 121             Roosevelt    35.0
# 122           Santa Clara   227.0
# 123             Snowville     2.0
# 124           Spring Glen     5.0
# 125           Spring Glen     5.0
# 126            Springdale    16.0
# 127              Stockton    18.0
# 128              Stoddard     2.0
# 129             Sunnyside     1.0
# 130                Sunset    19.0
# 131                Sunset    19.0
# 132            Sutherland    12.0
# 133              Syracuse     5.0
# 134               Tabiona     1.0
# 135          Taylorsville    12.0
# 136      Thompson Springs     2.0
# 476                 Platt     1.0
# 477                Hansen     1.0
# 478             Manhattan    17.0
# 479               O'Neill     1.0
# 480               Wallace     4.0
# 481              Moffitts     1.0
# 482                Eccles     2.0
# 483                 Cross     3.0
# 484              Lovelock     1.0
# 485              Stephens     1.0
# 486              Stephens     1.0
# 487                 Olsen     2.0
# 488               Burnett     4.0
# 489           Burch Creek     1.0
# 490           Cedar Ridge     1.0
# 491                Allred     1.0
# 492              Shamrock     2.0
# 493               Esquire     5.0
# 494            North Park     3.0
# 495            North Park     3.0
# 496               Terrace     4.0
# 497     Arlington Heights     1.0
# 498                 Irene     1.0
# 499             Wakefield     1.0
# 500          Garden Grove     3.0
# 501             Highlands     1.0
# 502              Chandler     1.0
# 503                 Major     2.0
# 504              Holbrook     1.0
# 505              Sunshine     1.0
# 506                 Villa    21.0
# 507           Browns Park     2.0
# 508              Pleasant     1.0
# 509              Lakeland     1.0
# 510           Quail Creek     2.0
# 511                  King     1.0
# 512         Mountain View     5.0
# 513                Lester     1.0
# 514               Newport     2.0
# 515                Thomas     8.0
# 516              Colorado  1971.0
# 517                Hanson     1.0
# 518           Hot Springs    14.0
# 519               Marsden     1.0
# 520          Rock Springs    21.0
# 521              Superior     1.0
# 522         Williamsburgh     1.0
# 523                Blaine     1.0
# 524               Bullock    11.0
# 525                 Butte    24.0
# 526              Cummings     1.0
# 527        Salt Lake City  5323.0
# 528               Diamond     1.0
# 529                Milton     2.0
# 530                 Paria    95.0
# 531          Saint George   625.0
# 532             Elk Ridge    11.0
# 533                Daniel     2.0
# 534      East Carbon City     1.0
# 535            Heber City    69.0
# 536            Sandy City     1.0
# 537               Portage     1.0
# 538           Rush Valley    20.0
# 539                Garden     1.0
# 540             Millcreek     4.0
# 541     Emigration Canyon     5.0
#
# [542 rows x 23 columns]

# %%
utah_map = folium.Map(location=[39, -111], zoom_start=5)

min_number = 1

sub_df = utah_df#[utah_df.count >= min_number]

lat = list(sub_df["PRIM_LAT_DEC"])
long = list(sub_df["PRIM_LONG_DEC"])
rad = list(sub_df["count"])
name = list(sub_df["FEATURE_NAME"])

for lt,ln,r,n in zip(lat,long,rad,name):
    folium.CircleMarker(location = [lt,ln],
                        popup=n,
                        tiles='Stamen Terrain',
                        radius = 1).add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bb3108f00a1740f1b46ee449d031c25b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bb3108f00a1740f1b46ee449d031c25b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bb3108f00a1740f1b46ee449d031c25b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bb3108f00a1740f1b46ee449d031c25b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%20-111.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
min_number = 1

sub_df = utah_df#[ut_usgs_df.FEATURE_COUNTS >= min_number]

county_counts = pd.DataFrame(sub_df['COUNTY_NAME'].value_counts().reset_index())
county_counts.columns = ['county_name', 'loc_count']
total_count = []
for county in county_counts.county_name.tolist():
    #sub_df = ut_usgs_df[ut_usgs_df.COUNTY_NAME == county]
    total_count.append(sub_df[sub_df.COUNTY_NAME == county]['count'].sum())

county_counts['total_count'] = total_count

county_counts
# Out:
#    county_name  loc_count  total_count
# 0    Salt Lake        114       8426.0
# 1        Davis         51        671.0
# 2        Weber         40       1897.0
# 3         Utah         37       1399.0
# 4    Box Elder         24        715.0
# 5        Cache         23        790.0
# 6   Washington         23       2345.0
# 7      Millard         21        203.0
# 8       Carbon         19        429.0
# 9       Tooele         18        405.0
# 10     Sanpete         15        265.0
# 11      Uintah         14        220.0
# 12      Sevier         13        244.0
# 13      Summit         12        596.0
# 14        Juab         11        161.0
# 15      Beaver         10        147.0
# 16       Emery         10        435.0
# 17    Duchesne          9         98.0
# 18       Grand          9         82.0
# 19     Wasatch          9        150.0
# 20    Garfield          9         67.0
# 21        Iron          9        430.0
# 22    San Juan          9        189.0
# 23       Wayne          8        437.0
# 24        Kane          7        236.0
# 25      Morgan          6         33.0
# 26        Rich          6         34.0
# 27       Piute          5        107.0
# 28     Daggett          1         50.0

# %%
sub_df[sub_df.COUNTY_NAME == 'Washington']
# Out:
#      Unnamed: 0  FEATURE_ID  FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 35      1329057     1440940    Enterprise  Populated Place          UT
# 71      1317520     1428951     Hurricane  Populated Place          UT
# 80      1317952     1429398      LaVerkin  Populated Place          UT
# 120     1320458     1431946     Rockville  Populated Place          UT
# 122     1320743     1432234   Santa Clara  Populated Place          UT
# 126     1321368     1432867    Springdale  Populated Place          UT
# 142     1322381     1433898        Virgin  Populated Place          UT
# 167     1325659     1437504   Bloomington  Populated Place          UT
# 191     1325725     1437570       Grafton  Populated Place          UT
# 194     1325731     1437576       Gunlock  Populated Place          UT
# 196     1325738     1437583    Harrisburg  Populated Place          UT
# 223     1325791     1437636     Middleton  Populated Place          UT
# 237     1325839     1437684    Shunesburg  Populated Place          UT
# 273     1327753     1439624       Central  Populated Place          UT
# 311     1330585     1442480         Leeds  Populated Place          UT
# 336     1331902     1443808   New Harmony  Populated Place          UT
# 355     1332498     1444412   Pine Valley  Populated Place          UT
# 356     1332520     1444434       Pintura  Populated Place          UT
# 377     1333679     1445602   Silver Reef  Populated Place          UT
# 388     1334722     1446655   Toquerville  Populated Place          UT
# 401     1335081     1447019    Washington  Populated Place          UT
# 415     1338109     1450387       Hildale  Populated Place          UT
# 531     1342412     1455098  Saint George  Populated Place          UT
#
#      STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS PRIM_LONG_DMS  \
# 35              49  Washington            53.0         373425N      1134309W
# 71              49  Washington            53.0         371031N      1131724W
# 80              49  Washington            53.0         371204N      1131611W
# 120             49  Washington            53.0         370940N      1130218W
# 122             49  Washington            53.0         370759N      1133915W
# 126             49  Washington            53.0         371120N      1125955W
# 142             49  Washington            53.0         371230N      1131118W
# 167             49  Washington            53.0         370248N      1133622W
# 191             49  Washington            53.0         371002N      1130448W
# 194             49  Washington            53.0         371710N      1134548W
# 196             49  Washington            53.0         371221N      1132340W
# 223             49  Washington            53.0         370715N      1133227W
# 237             49  Washington            53.0         370929N      1125840W
# 273             49  Washington            53.0         372500N      1133728W
# 311             49  Washington            53.0         371419N      1132133W
# 336             49  Washington            53.0         372846N      1131835W
# 355             49  Washington            53.0         372328N      1133051W
# 356             49  Washington            53.0         372027N      1131627W
# 377             49  Washington            53.0         371510N      1132204W
# 388             49  Washington            53.0         371512N      1131705W
# 401             49  Washington            53.0         370750N      1133030W
# 415             49  Washington            53.0         370013N      1125801W
# 531             49  Washington            53.0         370615N      1133503W
#
#      ...  SOURCE_LONG_DMS  SOURCE_LAT_DEC SOURCE_LONG_DEC ELEV_IN_M  \
# 35   ...              NaN             NaN             NaN    1620.0
# 71   ...              NaN             NaN             NaN     988.0
# 80   ...              NaN             NaN             NaN     973.0
# 120  ...              NaN             NaN             NaN    1142.0
# 122  ...              NaN             NaN             NaN     841.0
# 126  ...              NaN             NaN             NaN    1191.0
# 142  ...              NaN             NaN             NaN    1102.0
# 167  ...              NaN             NaN             NaN     771.0
# 191  ...              NaN             NaN             NaN    1119.0
# 194  ...              NaN             NaN             NaN    1112.0
# 196  ...              NaN             NaN             NaN     916.0
# 223  ...              NaN             NaN             NaN     871.0
# 237  ...              NaN             NaN             NaN    1213.0
# 273  ...              NaN             NaN             NaN    1598.0
# 311  ...              NaN             NaN             NaN    1061.0
# 336  ...              NaN             NaN             NaN    1619.0
# 355  ...              NaN             NaN             NaN    1992.0
# 356  ...              NaN             NaN             NaN    1246.0
# 377  ...              NaN             NaN             NaN    1155.0
# 388  ...              NaN             NaN             NaN    1031.0
# 401  ...              NaN             NaN             NaN     851.0
# 415  ...              NaN             NaN             NaN    1537.0
# 531  ...              NaN             NaN             NaN     822.0
#
#      ELEV_IN_FT             MAP_NAME  DATE_CREATED  DATE_EDITED         place  \
# 35       5315.0           Enterprise    12/31/1979   03/21/2008    Enterprise
# 71       3241.0            Hurricane    12/31/1979   03/21/2008     Hurricane
# 80       3192.0            Hurricane    12/31/1979   03/21/2008      LaVerkin
# 120      3747.0      Springdale West    12/31/1979   03/21/2008     Rockville
# 122      2759.0          Santa Clara    12/31/1979   03/21/2008   Santa Clara
# 126      3907.0      Springdale East    12/31/1979   03/21/2008    Springdale
# 142      3615.0               Virgin    12/31/1979   03/21/2008        Virgin
# 167      2529.0         Saint George    12/31/1979          NaN   Bloomington
# 191      3671.0      Springdale West    12/31/1979          NaN       Grafton
# 194      3648.0              Gunlock    12/31/1979          NaN       Gunlock
# 196      3005.0  Harrisburg Junction    12/31/1979   02/15/2006    Harrisburg
# 223      2858.0         Saint George    12/31/1979          NaN     Middleton
# 237      3980.0      Springdale East    12/31/1979          NaN    Shunesburg
# 273      5243.0         Central East    12/31/1979   01/29/2011       Central
# 311      3481.0            Hurricane    12/31/1979   03/21/2008         Leeds
# 336      5312.0          New Harmony    12/31/1979   03/21/2008   New Harmony
# 355      6535.0         Central East    12/31/1979   01/29/2011   Pine Valley
# 356      4088.0              Pintura    12/31/1979          NaN       Pintura
# 377      3789.0              Pintura    12/31/1979          NaN   Silver Reef
# 388      3383.0              Pintura    12/31/1979   03/21/2008   Toquerville
# 401      2792.0           Washington    12/31/1979   03/21/2008    Washington
# 415      5043.0              Hildale    02/25/1989   03/21/2008       Hildale
# 531      2697.0         Saint George    12/31/1979   03/21/2008  Saint George
#
#     count
# 35      4
# 71     41
# 80      1
# 120    51
# 122   227
# 126    16
# 142    26
# 167    12
# 191     7
# 194    14
# 196    22
# 223     1
# 237     4
# 273     1
# 311     3
# 336     7
# 355    29
# 356     8
# 377     8
# 388     6
# 401  1230
# 415     2
# 531     1
#
# [23 rows x 23 columns]

# %%
#Import Libraries
import geopandas as gpd
import pandas as pd
import numpy as np
import folium
from folium.features import GeoJsonTooltip

#Read the geoJSON file using geopandas
geojson = gpd.read_file('spatial history/georef-united-states-of-america-county.geojson')
geojson=geojson[geojson['ste_name'] == "Utah"]

ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

folium.Choropleth(geo_data=geojson).add_to(ut_county_map)

df_final = geojson.merge(county_counts, left_on="coty_name", right_on="county_name", how="outer") 
df_final = df_final[~df_final['geometry'].isna()]
df_final
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-77-75b695f0feb3> in <module>
#       7
#       8 #Read the geoJSON file using geopandas
# ----> 9 geojson = gpd.read_file('spatial history/georef-united-states-of-america-county.geojson')
#      10 geojson=geojson[geojson['ste_name'] == "Utah"]
#      11
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     201                 )
#     202
# --> 203             return GeoDataFrame.from_features(
#     204                 f_filt, crs=crs, columns=columns + ["geometry"]
#     205             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py in from_features(cls, features, crs, columns)
#     585             row.update(feature["properties"])
#     586             rows.append(row)
# --> 587         return GeoDataFrame(rows, columns=columns, crs=crs)
#     588
#     589     @classmethod
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py in __init__(self, geometry, crs, *args, **kwargs)
#     107         # need to set this before calling self['geometry'], because
#     108         # getitem accesses crs
# --> 109         self._crs = CRS.from_user_input(crs) if crs else None
#     110
#     111         # set_geometry ensures the geometry data have the proper dtype,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py in from_user_input(value, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py in __init__(self, projparams, **kwargs)
#
# pyproj/_crs.pyx in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: epsg:4326: (Internal Proj Error: proj_create: no database context specified)

# %%
ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

map_variable = 'total_count' #possible variables: 'loc_count' & 'total_count'

folium.Choropleth(
            geo_data=geojson,
            data=df_final,
            columns=['coty_code', map_variable],  #Here we tell folium to get the county fips and plot new_cases_7days metric for each county
            key_on='feature.properties.coty_code', #Here we grab the geometries/county boundaries from the geojson file using the key 'coty_code' which is the same as county fips
            #threshold_scale=(df_final[map_variable].quantile((0, 0.2, 0.4, 0.6, 0.8, 1))).tolist(), #we can create our own custom scale if we like.
            fill_color='YlOrRd',
            nan_fill_color="White", #Use white color if there is no data available for the county
            fill_opacity=0.7,
            line_opacity=0.2,
            legend_name='', #title of the legend
            highlight=True,
            line_color='black').add_to(ut_county_map)

ut_county_map
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-69-cd7ba5c6e7ee> in <module>
#       3 map_variable = 'total_count' #possible variables: 'loc_count' & 'total_count'
#       4
# ----> 5 folium.Choropleth(
#       6             geo_data=geojson,
#       7             data=df_final,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1287                 smooth_factor=smooth_factor)
#    1288         else:
# -> 1289             self.geojson = GeoJson(
#    1290                 geo_data,
#    1291                 style_function=style_function,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     497         self.marker = marker
#     498
# --> 499         self.data = self.process_data(data)
#     500
#     501         if self.style or self.highlight:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in process_data(self, data)
#     539             self.embed = True
#     540             if hasattr(data, 'to_crs'):
# --> 541                 data = data.to_crs('EPSG:4326')
#     542             return json.loads(json.dumps(data.__geo_interface__))
#     543         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py in to_crs(self, crs, epsg, inplace)
#    1245         else:
#    1246             df = self.copy()
# -> 1247         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1248         df.geometry = geom
#    1249         df.crs = geom.crs
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geoseries.py in to_crs(self, crs, epsg)
#    1026         """
#    1027         return GeoSeries(
# -> 1028             self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1029         )
#    1030
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/array.py in to_crs(self, crs, epsg)
#     783             )
#     784         if crs is not None:
# --> 785             crs = CRS.from_user_input(crs)
#     786         elif epsg is not None:
#     787             crs = CRS.from_epsg(epsg)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py in from_user_input(value, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py in __init__(self, projparams, **kwargs)
#
# pyproj/_crs.pyx in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: EPSG:4326: (Internal Proj Error: proj_create: no database context specified)
