# %% [markdown]
# # Spatial History
# Intro to Digital History, 4/4/2022
# Portions adapted from https://melaniewalsh.github.io/Intro-Cultural-Analytics/07-Mapping/01-Mapping.html

# %%
#!pip install geopy
#!pip install folium
#!pip install geopandas

# %%
from geopy.geocoders import Nominatim
import folium

geolocator = Nominatim(user_agent="YOUR NAME's mapping app", timeout=2)

# %%
loc = "University of Utah"

location = geolocator.geocode(loc)

location
# Out:
# Location(University of Utah, 201, Presidents Circle, Salt Lake City, Salt Lake County, Utah, 84112, United States, (40.762813699999995, -111.83687191368261, 0.0))

# %%
print(location.address)
# Out:
# University of Utah, 201, Presidents Circle, Salt Lake City, Salt Lake County, Utah, 84112, United States

# %%
print(location.latitude, location.longitude)
# Out:
# 40.762813699999995 -111.83687191368261

# %%
print(f"Class: {location.raw['class']} \nType: {location.raw['type']}")
# Out:
# Class: amenity
# Type: university

# %%
utah_map = folium.Map(location=[location.latitude, location.longitude],
                     zoom_start=14)

folium.Marker(location=[location.latitude, location.longitude],
             popup="University of Utah").add_to(utah_map)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bf614a5ac9274ea9876f7e874f6f8f9f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bf614a5ac9274ea9876f7e874f6f8f9f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bf614a5ac9274ea9876f7e874f6f8f9f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bf614a5ac9274ea9876f7e874f6f8f9f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.762813699999995%2C%20-111.83687191368261%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
utah_map = folium.Map(location=[location.latitude, location.longitude],
                     zoom_start=10)

folium.CircleMarker(location=[location.latitude, location.longitude],
                    radius=10,
                    color = 'black',
                    fill_color = 'red',
                    fill_opacity = 0.6,
                    popup = "University of Utah").add_to(utah_map)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2e493912820f4ec6ae109e9b03df9400%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2e493912820f4ec6ae109e9b03df9400%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2e493912820f4ec6ae109e9b03df9400%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2e493912820f4ec6ae109e9b03df9400%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.762813699999995%2C%20-111.83687191368261%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
possible_locations = geolocator.geocode("University of Utah", exactly_one=False)

for location in possible_locations:
    print(location.address)
    print(location.latitude, location.longitude)
    print(f"Importance: {location.raw['importance']}")
# Out:
# University of Utah, 201, Presidents Circle, Salt Lake City, Salt Lake County, Utah, 84112, United States
# 40.762813699999995 -111.83687191368261
# Importance: 0.8557694184669417
# Department of Linguistics, University of Utah, 255, Central Campus Drive, Salt Lake City, Salt Lake County, Utah, 84112, United States
# 40.7634795 -111.8408017
# Importance: 0.31100000000000005
# Outdoor Adventures, Presidents Circle, Salt Lake City, Salt Lake County, Utah, 84112, United States
# 40.7655129 -111.838165
# Importance: 0.11100000000000002

# %% [markdown]
# # Where is Utah History?

# %% [markdown]
# Using Named Entity Recognition

# %%
#!pip install -U spacy
#!python -m spacy download en_core_web_sm
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
import pandas as pd

#Load UHQ data into a pandas dataframe
df = pd.read_excel("../UHQ_FULL_EDITED.xlsx")

# %%
#Look at the first article in our database
text = df.text.tolist()[0]

#Run Named Entity Recognition on the text
document = nlp(text)

displacy.render(document[:500], style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     evening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 29, 1890
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 6:30 p.m.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , just past the corner of
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C Street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  and
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First Avenue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Salt Lake City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . It was almost dark; the sky was overcast and the weather portended
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of summer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frank C. Hall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thirty-eight year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  engineer by training currently employed as a barkeeper at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Mint Saloon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , strolled along in the company of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ann Hart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a widow of about his age. Hall was estranged from his wife and had custody of his
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  young children; they boarded with Hart at 277 C Street. The pair chatted amiably as they made their way toward
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brigham Street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# .</br>As they passed the corner of C and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  streets, a young woman stepped out from behind a tree, said something unintelligible, and fired a single shot, striking
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in the head and killing him instantly. Her name was
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amanda Olson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and she was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     twenty-two years old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  She was employed at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pearson’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  knitting factory and had recently moved with her parents to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     318 Sixth Avenue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Olsons
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’ new house was just around the corner from their previous residence at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     286 C Street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , which was across the street on the other end of the b

# %%
#Create a list of all location (GPE) entities in the text
location_list = []
for named_entity in document.ents:
    if named_entity.label_ == "GPE":
        location_list.append(named_entity.text.replace("’s", ""))

#Print our list
location_list
# Out:
# ['Salt Lake City',
#  'Salt Lake City',
#  'Salt Lake City',
#  'Utah',
#  'Salt Lake City',
#  'Amanda',
#  'Amanda',
#  'California',
#  'Salt Lake City',
#  'Park City',
#  'New York',
#  'Utah',
#  'Ogden',
#  'Washington',
#  'Utah',
#  'Utah',
#  'Utah',
#  'Michigan',
#  'Salt Lake City',
#  'Salt Lake City',
#  'Utah',
#  'Utah',
#  'New York',
#  'Chicago',
#  'Chicago',
#  'Herald',
#  'Russia']

# %% [markdown]
# ### Question: What are some potential problems that you see with this list?

# %%
#Is Amanda a place???
loc = "Amanda"

location = geolocator.geocode(loc)
location
# Out:
# Location(Amanda, Fairfield County, Ohio, United States, (39.649508, -82.7443367, 0.0))

# %%
#We can use the geolocator library to locate the latitude and longitude for each location. 

location_tally = Counter(location_list)

location_df = pd.DataFrame(location_tally.most_common(), columns=['location', 'count'])

loc_list = location_df.location.tolist()

lat = []
lon = []

for l in loc_list:
    temp_loc = geolocator.geocode(l)
    lat.append(temp_loc.latitude)
    lon.append(temp_loc.longitude)

location_df['lat'] = lat
location_df['lon'] = lon
location_df
# Out:
#           location  count        lat         lon
# 0   Salt Lake City      7  40.759620 -111.886798
# 1             Utah      7  39.422519 -111.714358
# 2           Amanda      2  39.649508  -82.744337
# 3         New York      2  40.712728  -74.006015
# 4          Chicago      2  41.875562  -87.624421
# 5       California      1  36.701463 -118.755997
# 6        Park City      1  40.646092 -111.497996
# 7            Ogden      1  41.223005 -111.973843
# 8       Washington      1  38.895037  -77.036543
# 9         Michigan      1  43.621195  -84.682435
# 10          Herald      1  37.966435  -88.181427
# 11          Russia      1  64.686314   97.745306

# %% [markdown]
# Note that this returns a single point in space. Are Utah, California, or even Russia one point on a map?

# %%
world_map = folium.Map(location=[42, -102], zoom_start=1)
location_df = location_df.dropna(subset=['lat', 'lon'])

lat = list(location_df["lat"])
long = list(location_df["lon"])
rad = list(location_df["count"])
name = list(location_df["location"])

for lt,ln,r,n in zip(lat,long,rad,name):
    folium.CircleMarker(location = [lt,ln],
                        popup=n,
                        radius = r).add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_21af1fb9abc342919037bb11818119ae%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_21af1fb9abc342919037bb11818119ae%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_21af1fb9abc342919037bb11818119ae%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_21af1fb9abc342919037bb11818119ae%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0%2C%20-102.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Using US Geological Survey Data

# %%
import pandas as pd
usgs_df = pd.read_csv("UTAH_USGS.csv")
len(usgs_df)
# Out:
# 31913

# %%
usgs_df[usgs_df.STATE_ALPHA == "UT"].FEATURE_CLASS.value_counts()[:20]
# Out:
# Valley             5730
# Populated Place    3618
# Spring             2554
# Stream             2545
# Summit             2351
# Locale             1926
# Church             1577
# Reservoir           961
# Building            906
# Lake                899
# School              870
# Flat                775
# Mine                704
# Canal               576
# Ridge               554
# Cemetery            531
# Park                455
# Basin               445
# Civil               403
# Dam                 384
# Name: FEATURE_CLASS, dtype: int64

# %%
usgs_df[(usgs_df.STATE_ALPHA == "UT") & (usgs_df.FEATURE_CLASS == "Mine")]
# Out:
#        Unnamed: 0  FEATURE_ID    FEATURE_NAME FEATURE_CLASS STATE_ALPHA  \
# 148       1313671     1425037   Aberdeen Mine          Mine          UT
# 172       1313695     1425061            Ajax          Mine          UT
# 175       1313698     1425064          Alaska          Mine          UT
# 191       1313714     1425080      Allah Mine          Mine          UT
# 210       1313733     1425099   Alvarado Mine          Mine          UT
# ...           ...         ...             ...           ...         ...
# 29257     1342803     1455545    Tip Top Mine          Mine          UT
# 29419     1342965     1455712  Gray Daun Mine          Mine          UT
# 29542     1343088     1455845       Utah Mine          Mine          UT
# 29632     1469262     1585926   Brillian Mine          Mine          UT
# 29841     1794382     1947885       Cuba Mine          Mine          UT
#
#        STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 148               49      Carbon             7.0         394218N
# 172               49        Juab            23.0         395538N
# 175               49        Juab            23.0         395441N
# 191               49        Juab            23.0         395027N
# 210               49      Tooele            45.0         401013N
# ...              ...         ...             ...             ...
# 29257             49      Tooele            45.0         402730N
# 29419             49    San Juan            37.0         382015N
# 29542             49        Utah            49.0         395624N
# 29632             49       Emery            15.0         385241N
# 29841             49    San Juan            37.0         380705N
#
#       PRIM_LONG_DMS  ...  PRIM_LONG_DEC  SOURCE_LAT_DMS SOURCE_LONG_DMS  \
# 148        1104719W  ...    -110.788492             NaN             NaN
# 172        1120646W  ...    -112.112723             NaN             NaN
# 175        1120535W  ...    -112.093000             NaN             NaN
# 191        1122307W  ...    -112.385228             NaN             NaN
# 210        1134842W  ...    -113.811665             NaN             NaN
# ...             ...  ...            ...             ...             ...
# 29257      1121949W  ...    -112.330226             NaN             NaN
# 29419      1090547W  ...    -109.096497             NaN             NaN
# 29542      1120559W  ...    -112.099667             NaN             NaN
# 29632      1103346W  ...    -110.562658             NaN             NaN
# 29841      1090707W  ...    -109.118720             NaN             NaN
#
#       SOURCE_LAT_DEC  SOURCE_LONG_DEC  ELEV_IN_M  ELEV_IN_FT  \
# 148              NaN              NaN     2182.0      7159.0
# 172              NaN              NaN     2169.0      7116.0
# 175              NaN              NaN     2032.0      6667.0
# 191              NaN              NaN     1960.0      6430.0
# 210              NaN              NaN     1600.0      5249.0
# ...              ...              ...        ...         ...
# 29257            NaN              NaN     1965.0      6447.0
# 29419            NaN              NaN     2018.0      6621.0
# 29542            NaN              NaN     2228.0      7310.0
# 29632            NaN              NaN     2012.0      6601.0
# 29841            NaN              NaN     2008.0      6588.0
#
#                 MAP_NAME DATE_CREATED DATE_EDITED
# 148               Helper   12/31/1979         NaN
# 172               Eureka   12/31/1979         NaN
# 175               Eureka   12/31/1979         NaN
# 191         Cherry Creek   12/31/1979         NaN
# 210            Gold Hill   12/31/1979         NaN
# ...                  ...          ...         ...
# 29257           Stockton   02/25/1989         NaN
# 29419           Ray Mesa   10/01/1992         NaN
# 29542             Eureka   10/01/1992         NaN
# 29632  Drowned Hole Draw   06/05/1979  12/21/2010
# 29841       Summit Point   01/30/2002         NaN
#
# [704 rows x 21 columns]

# %%
feature = "Populated Place"
ut_usgs_df = usgs_df[(usgs_df.STATE_ALPHA == "UT") & (usgs_df.FEATURE_CLASS == feature)]

# %%
ut_usgs_df[ut_usgs_df.FEATURE_NAME == "Salt Lake City"]
# Out:
#        Unnamed: 0  FEATURE_ID    FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 28787     1342331     1454997  Salt Lake City  Populated Place          UT
#
#        STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 28787             49   Salt Lake            35.0         404539N
#
#       PRIM_LONG_DMS  ...  PRIM_LONG_DEC  SOURCE_LAT_DMS SOURCE_LONG_DMS  \
# 28787      1115328W  ...    -111.891047             NaN             NaN
#
#       SOURCE_LAT_DEC  SOURCE_LONG_DEC  ELEV_IN_M  ELEV_IN_FT  \
# 28787            NaN              NaN     1300.0      4265.0
#
#                    MAP_NAME DATE_CREATED DATE_EDITED
# 28787  Salt Lake City North   12/31/1979  05/11/2011
#
# [1 rows x 21 columns]

# %%
year_begin = 1928 #UHQ first year is 1928
year_end = 2021 #UHQ end year is 2021

#creating string containing all UHQ texts
df2 = df[(df['text'].notna()) & (df['year'] >= year_begin) & (df['year'] <= year_end)].reset_index()

full_uhq_texts = ' '.join([str(elem) for elem in df2.text.tolist()])

# %%
usgs_counts = []

for fn in ut_usgs_df.FEATURE_NAME.tolist():
    usgs_counts.append(full_uhq_texts.count(fn))
    
ut_usgs_df['FEATURE_COUNTS'] = usgs_counts
# Out:
# <ipython-input-24-7b0bfdab6c26>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ut_usgs_df['FEATURE_COUNTS'] = usgs_counts

# %%
len(usgs_counts), len(ut_usgs_df)
# Out:
# (3618, 3618)

# %%
ut_usgs_df
# Out:
#        Unnamed: 0  FEATURE_ID           FEATURE_NAME    FEATURE_CLASS  \
# 85         347050      395885                  Utida  Populated Place
# 150       1313673     1425039                Abraham  Populated Place
# 161       1313684     1425050             Adamsville  Populated Place
# 207       1313730     1425096               Altamont  Populated Place
# 208       1313731     1425097                Altonah  Populated Place
# ...           ...         ...                    ...              ...
# 31218     2199708     2708039  Covered Bridge Canyon  Populated Place
# 31811     2260035     2783908             Interlaken  Populated Place
# 31838     2263734     2791542        Cedar Highlands  Populated Place
# 31864     2268987     2797924      Emigration Canyon  Populated Place
# 31896     2276439     2807120             East Basin  Populated Place
#
#       STATE_ALPHA  STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 85             UT             49       Cache             5.0         415957N
# 150            UT             49     Millard            27.0         392348N
# 161            UT             49      Beaver             1.0         381530N
# 207            UT             49    Duchesne            13.0         402134N
# 208            UT             49    Duchesne            13.0         402405N
# ...           ...            ...         ...             ...             ...
# 31218          UT             49        Utah            49.0         400209N
# 31811          UT             49     Wasatch            51.0         403230N
# 31838          UT             49        Iron            21.0         373815N
# 31864          UT             49   Salt Lake            35.0         404612N
# 31896          UT             49      Summit            43.0         404325N
#
#       PRIM_LONG_DMS  ...  SOURCE_LAT_DMS  SOURCE_LONG_DMS SOURCE_LAT_DEC  \
# 85         1115831W  ...             NaN              NaN            NaN
# 150        1124305W  ...             NaN              NaN            NaN
# 161        1124738W  ...             NaN              NaN            NaN
# 207        1101711W  ...             NaN              NaN            NaN
# 208        1101738W  ...             NaN              NaN            NaN
# ...             ...  ...             ...              ...            ...
# 31218      1113312W  ...             NaN              NaN            NaN
# 31811      1112823W  ...             NaN              NaN            NaN
# 31838      1130243W  ...             NaN              NaN            NaN
# 31864      1114535W  ...             NaN              NaN            NaN
# 31896      1112920W  ...             NaN              NaN            NaN
#
#       SOURCE_LONG_DEC  ELEV_IN_M  ELEV_IN_FT           MAP_NAME  DATE_CREATED  \
# 85                NaN     1411.0      4629.0            Trenton    12/31/1979
# 150               NaN     1400.0      4593.0         Sutherland    12/31/1979
# 161               NaN     1685.0      5528.0         Adamsville    12/31/1979
# 207               NaN     1947.0      6388.0           Altamont    12/31/1979
# 208               NaN     2034.0      6673.0            Altonah    12/31/1979
# ...               ...        ...         ...                ...           ...
# 31218             NaN     1559.0      5115.0  Spanish Fork Peak    11/04/2011
# 31811             NaN     1805.0      5922.0         Heber City    04/28/2016
# 31838             NaN     2311.0      7582.0         Cedar City    05/17/2018
# 31864             NaN     1639.0      5377.0       Fort Douglas    03/04/2019
# 31896             NaN     1986.0      6516.0     Park City East    05/08/2020
#
#       DATE_EDITED FEATURE_COUNTS
# 85            NaN              2
# 150           NaN            335
# 161           NaN              1
# 207    03/21/2008              0
# 208           NaN              1
# ...           ...            ...
# 31218  11/08/2011              0
# 31811         NaN              0
# 31838  05/06/2021              0
# 31864         NaN             65
# 31896         NaN              0
#
# [3618 rows x 22 columns]

# %% [markdown]
# Question: Do you notice any potential problems with the displayed data above? Note that "Abraham" appears in UHQ 335 times, but do you think all of these occurances refer to the location?

# %%
place_name = "Salt Lake City"
ut_usgs_df[ut_usgs_df.FEATURE_NAME == place_name]
# Out:
#        Unnamed: 0  FEATURE_ID    FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 28787     1342331     1454997  Salt Lake City  Populated Place          UT
#
#        STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 28787             49   Salt Lake            35.0         404539N
#
#       PRIM_LONG_DMS  ...  SOURCE_LAT_DMS  SOURCE_LONG_DMS SOURCE_LAT_DEC  \
# 28787      1115328W  ...             NaN              NaN            NaN
#
#       SOURCE_LONG_DEC  ELEV_IN_M  ELEV_IN_FT              MAP_NAME  \
# 28787             NaN     1300.0      4265.0  Salt Lake City North
#
#        DATE_CREATED DATE_EDITED FEATURE_COUNTS
# 28787    12/31/1979  05/11/2011           6049
#
# [1 rows x 22 columns]

# %%
utah_map = folium.Map(location=[39, -111], zoom_start=5)

min_number = 1

sub_df = ut_usgs_df[ut_usgs_df.FEATURE_COUNTS >= min_number]

lat = list(sub_df["PRIM_LAT_DEC"])
long = list(sub_df["PRIM_LONG_DEC"])
rad = list(sub_df["FEATURE_COUNTS"])
name = list(sub_df["FEATURE_NAME"])

for lt,ln,r,n in zip(lat,long,rad,name):
    folium.CircleMarker(location = [lt,ln],
                        popup=n,
                        tiles='Stamen Terrain',
                        radius = 1).add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d664e3d9fea04b9a99a2179f31880742%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d664e3d9fea04b9a99a2179f31880742%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d664e3d9fea04b9a99a2179f31880742%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d664e3d9fea04b9a99a2179f31880742%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%20-111.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# Try adjusting the "min_number" variable to see how your results change. Note that this approach is great at showing all of the places in Utah that are referenced at least 'n' number of times, but not great at showing volume. How much more likely is Salt Lake City or a place in Salt Lake County to appear than other locations in Utah? For that, we can turn to choropleth maps.

# %% [markdown]
# ## Choropleth Maps

# %%
#Import Libraries
import geopandas as gpd
import pandas as pd
import numpy as np
import folium
from folium.features import GeoJsonTooltip

#Read the geoJSON file using geopandas
geojson = gpd.read_file('georef-united-states-of-america-county.geojson')
geojson=geojson[geojson['ste_name'] == "Utah"]

ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

folium.Choropleth(geo_data=geojson).add_to(ut_county_map)
ut_county_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_985276916b4a49e19a93490c3b2bf538%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_985276916b4a49e19a93490c3b2bf538%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_985276916b4a49e19a93490c3b2bf538%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_985276916b4a49e19a93490c3b2bf538%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.5%2C%20-111.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
min_number = 1

sub_df = ut_usgs_df[ut_usgs_df.FEATURE_COUNTS >= min_number]

county_counts = pd.DataFrame(sub_df['COUNTY_NAME'].value_counts().reset_index())
county_counts.columns = ['county_name', 'loc_count']
total_count = []
for county in county_counts.county_name.tolist():
    #sub_df = ut_usgs_df[ut_usgs_df.COUNTY_NAME == county]
    total_count.append(sub_df[sub_df.COUNTY_NAME == county]['FEATURE_COUNTS'].sum())

county_counts['total_count'] = total_count

county_counts
# Out:
#    county_name  loc_count  total_count
# 0    Salt Lake        304        36060
# 1        Davis        145        20336
# 2        Weber        113        12296
# 3         Utah         63         6595
# 4    Box Elder         46         2626
# 5      Millard         31         4759
# 6       Tooele         31         2948
# 7        Cache         31         2638
# 8   Washington         28         4519
# 9       Carbon         25         2078
# 10        Juab         24         1953
# 11      Summit         22         2473
# 12     Sanpete         21         1538
# 13      Sevier         21         3621
# 14    San Juan         20         1328
# 15      Uintah         20         1518
# 16        Iron         19         1419
# 17       Emery         18         3153
# 18      Beaver         15         1062
# 19    Duchesne         15         2070
# 20       Grand         14         1265
# 21    Garfield         14         1593
# 22     Wasatch         13          907
# 23       Wayne         11         1331
# 24      Morgan         10          870
# 25        Kane          9          804
# 26       Piute          9          509
# 27        Rich          7          662
# 28     Daggett          2           62

# %%
df_final = geojson.merge(county_counts, left_on="coty_name", right_on="county_name", how="outer") 
df_final = df_final[~df_final['geometry'].isna()]
df_final
# Out:
#    coty_code coty_gnis_code     coty_name_long ste_name coty_type  year  \
# 0      49037       01448032    San Juan County     Utah    county  2020
# 1      49043       01448035      Summit County     Utah    county  2020
# 2      49041       01448034      Sevier County     Utah    county  2020
# 3      49051       01448039     Wasatch County     Utah    county  2020
# 4      49021       01448025        Iron County     Utah    county  2020
# 5      49017       01448023    Garfield County     Utah    county  2020
# 6      49011       01448020       Davis County     Utah    county  2020
# 7      49009       01448019     Daggett County     Utah    county  2020
# 8      49029       01448028      Morgan County     Utah    county  2020
# 9      49035       01448031   Salt Lake County     Utah    county  2020
# 10     49057       01448042       Weber County     Utah    county  2020
# 11     49013       01448021    Duchesne County     Utah    county  2020
# 12     49031       01448029       Piute County     Utah    county  2020
# 13     49033       01448030        Rich County     Utah    county  2020
# 14     49039       01448033     Sanpete County     Utah    county  2020
# 15     49023       01455158        Juab County     Utah    county  2020
# 16     49005       01448017       Cache County     Utah    county  2020
# 17     49007       01448018      Carbon County     Utah    county  2020
# 18     49053       01448040  Washington County     Utah    county  2020
# 19     49003       01455966   Box Elder County     Utah    county  2020
# 20     49015       01448022       Emery County     Utah    county  2020
# 21     49001       01448015      Beaver County     Utah    county  2020
# 22     49019       01448024       Grand County     Utah    county  2020
# 23     49047       01448037      Uintah County     Utah    county  2020
# 24     49027       01448027     Millard County     Utah    county  2020
# 25     49045       01448036      Tooele County     Utah    county  2020
# 26     49055       01448041       Wayne County     Utah    county  2020
# 27     49049       01448038        Utah County     Utah    county  2020
# 28     49025       01448026        Kane County     Utah    county  2020
#
#    coty_area_code ste_code coty_fp_code   coty_name  \
# 0             USA       49          037    San Juan
# 1             USA       49          043      Summit
# 2             USA       49          041      Sevier
# 3             USA       49          051     Wasatch
# 4             USA       49          021        Iron
# 5             USA       49          017    Garfield
# 6             USA       49          011       Davis
# 7             USA       49          009     Daggett
# 8             USA       49          029      Morgan
# 9             USA       49          035   Salt Lake
# 10            USA       49          057       Weber
# 11            USA       49          013    Duchesne
# 12            USA       49          031       Piute
# 13            USA       49          033        Rich
# 14            USA       49          039     Sanpete
# 15            USA       49          023        Juab
# 16            USA       49          005       Cache
# 17            USA       49          007      Carbon
# 18            USA       49          053  Washington
# 19            USA       49          003   Box Elder
# 20            USA       49          015       Emery
# 21            USA       49          001      Beaver
# 22            USA       49          019       Grand
# 23            USA       49          047      Uintah
# 24            USA       49          027     Millard
# 25            USA       49          045      Tooele
# 26            USA       49          055       Wayne
# 27            USA       49          049        Utah
# 28            USA       49          025        Kane
#
#                                              geometry county_name  loc_count  \
# 0   POLYGON ((-109.92799 38.15188, -109.92719 38.1...    San Juan         20
# 1   POLYGON ((-111.26497 41.14404, -111.27467 41.1...      Summit         22
# 2   POLYGON ((-112.51850 38.51041, -112.44870 38.5...      Sevier         21
# 3   POLYGON ((-110.89166 39.89965, -110.89197 40.0...     Wasatch         13
# 4   POLYGON ((-114.04998 38.14876, -114.05004 38.0...        Iron         19
# 5   POLYGON ((-112.47868 38.14742, -112.47873 38.0...    Garfield         14
# 6   POLYGON ((-112.26022 40.76909, -112.14827 40.8...       Davis        145
# 7   POLYGON ((-109.04894 40.66260, -109.04909 40.7...     Daggett          2
# 8   POLYGON ((-111.42073 41.36131, -111.42401 41.3...      Morgan         10
# 9   POLYGON ((-111.59388 40.57706, -111.59070 40.5...   Salt Lake        304
# 10  POLYGON ((-111.51084 41.42310, -111.51735 41.4...       Weber        113
# 11  POLYGON ((-109.97640 40.80969, -109.98805 40.8...    Duchesne         15
# 12  POLYGON ((-112.44421 38.15000, -112.34472 38.1...       Piute          9
# 13  POLYGON ((-111.50781 41.99955, -111.50879 41.9...        Rich          7
# 14  POLYGON ((-111.64194 39.81287, -111.64206 39.7...     Sanpete         21
# 15  POLYGON ((-112.17980 40.01166, -112.18686 40.0...        Juab         24
# 16  POLYGON ((-111.50781 41.99955, -111.54244 41.9...       Cache         31
# 17  POLYGON ((-109.97681 39.80623, -110.06291 39.8...      Carbon         25
# 18  POLYGON ((-112.89919 37.00038, -112.89917 37.0...  Washington         28
# 19  POLYGON ((-112.15918 41.99838, -112.17315 42.0...   Box Elder         46
# 20  POLYGON ((-110.02540 38.49998, -110.04082 38.5...       Emery         18
# 21  POLYGON ((-114.04998 38.14876, -113.90718 38.1...      Beaver         15
# 22  POLYGON ((-110.02396 39.46927, -110.02412 39.4...       Grand         14
# 23  POLYGON ((-109.04894 40.66260, -109.12348 40.6...      Uintah         20
# 24  POLYGON ((-112.51539 38.57284, -112.51239 38.5...     Millard         31
# 25  POLYGON ((-112.17286 40.46706, -112.17185 40.4...      Tooele         31
# 26  POLYGON ((-111.30567 38.51017, -111.37573 38.5...       Wayne         11
# 27  POLYGON ((-112.17286 40.46706, -112.19027 40.4...        Utah         63
# 28  POLYGON ((-112.53857 37.00076, -112.49004 37.0...        Kane          9
#
#     total_count
# 0          1328
# 1          2473
# 2          3621
# 3           907
# 4          1419
# 5          1593
# 6         20336
# 7            62
# 8           870
# 9         36060
# 10        12296
# 11         2070
# 12          509
# 13          662
# 14         1538
# 15         1953
# 16         2638
# 17         2078
# 18         4519
# 19         2626
# 20         3153
# 21         1062
# 22         1265
# 23         1518
# 24         4759
# 25         2948
# 26         1331
# 27         6595
# 28          804

# %%
ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

map_variable = 'total_count' #possible variables: 'loc_count' & 'total_count'

folium.Choropleth(
            geo_data=geojson,
            data=df_final,
            columns=['coty_code', map_variable],  #Here we tell folium to get the county fips and plot new_cases_7days metric for each county
            key_on='feature.properties.coty_code', #Here we grab the geometries/county boundaries from the geojson file using the key 'coty_code' which is the same as county fips
            #threshold_scale=(df_final[map_variable].quantile((0, 0.2, 0.4, 0.6, 0.8, 1))).tolist(), #we can create our own custom scale if we like.
            fill_color='YlOrRd',
            nan_fill_color="White", #Use white color if there is no data available for the county
            fill_opacity=0.7,
            line_opacity=0.2,
            legend_name='', #title of the legend
            highlight=True,
            line_color='black').add_to(ut_county_map)

ut_county_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_66f0657aac8048a3b6df7a7ecd6cc046%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_66f0657aac8048a3b6df7a7ecd6cc046%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_66f0657aac8048a3b6df7a7ecd6cc046%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_66f0657aac8048a3b6df7a7ecd6cc046%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # Combining USGS and NER

# %%
# ##Takes a long time to run!
# import pandas as pd

# #Load UHQ data into a pandas dataframe
# df = pd.read_excel("UHQ_FULL_EDITED.xlsx")

# year_begin = 1928 #UHQ first year is 1928
# year_end = 2021 #UHQ end year is 2021

# #creating string containing all UHQ texts
# df2 = df[(df['text'].notna()) & (df['year'] >= year_begin) & (df['year'] <= year_end)].reset_index()


# #Look at the first article in our database
# texts = df2.text.tolist()

# places = []
# #Run Named Entity Recognition on the text
# for t in texts:
#     document = nlp(t)
#     for named_entity in document.ents:
#         if named_entity.label_ == "GPE":
#             places.append(named_entity.text.replace("’s", ""))
# len(places)

# places_tally = Counter(places)
# places_df = pd.DataFrame(places_tally.most_common(), columns=['place', 'count'])
# places_df.to_excel("ner_places.xlsx")

# %%
places_df = pd.read_excel('ner_places.xlsx')
places_df[:50]
# Out:
#                 place    count
# 0                Utah  20358.0
# 1      Salt Lake City   5323.0
# 2          California   2243.0
# 3   the United States   1985.0
# 4            Colorado   1971.0
# 5               Ogden   1615.0
# 6           Salt Lake   1373.0
# 7          Washington   1230.0
# 8             America   1179.0
# 9              Nevada    968.0
# 10         New Mexico    915.0
# 11           New York    899.0
# 12              Idaho    836.0
# 13            Arizona    831.0
# 14              Provo    816.0
# 15            Wyoming    711.0
# 16               U.S.    708.0
# 17           Missouri    652.0
# 18       Saint George    625.0
# 19      San Francisco    617.0
# 20            England    571.0
# 21             Denver    506.0
# 22           Illinois    494.0
# 23             Mexico    450.0
# 24          Park City    430.0
# 25      Carbon County    408.0
# 26             Oregon    403.0
# 27            Chicago    398.0
# 28            Fremont    386.0
# 29              Smoot    378.0
# 30      United States    370.0
# 31            Germany    370.0
# 32            Montana    346.0
# 33              Logan    340.0
# 34            Corinne    337.0
# 35         Cedar City    330.0
# 36          St. Louis    315.0
# 37               Ohio    312.0
# 38            Bingham    305.0
# 39           San Juan    291.0
# 40              Texas    290.0
# 41             France    288.0
# 42        Los Angeles    282.0
# 43       Fort Douglas    267.0
# 44               Iowa    258.0
# 45       Brigham City    258.0
# 46             Kansas    258.0
# 47          Utah Lake    257.0
# 48       Fort Bridger    251.0
# 49   Salt Lake County    234.0

# %%
usgs_df = pd.read_csv("UTAH_USGS.csv")
feature = "Populated Place"
ut_usgs_df = usgs_df[(usgs_df.STATE_ALPHA == "UT") & (usgs_df.FEATURE_CLASS == feature)]


place_match = []
place_miss = []

for p in places_df.place.tolist():
    if p in ut_usgs_df.FEATURE_NAME.tolist():
        place_match.append(p)
    else:
        place_miss.append(p)

# %%
utah_df = ut_usgs_df.merge(places_df, left_on="FEATURE_NAME", right_on="place", how="inner")
utah_df
# Out:
#      Unnamed: 0  FEATURE_ID       FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 0       1313684     1425050         Adamsville  Populated Place          UT
# 1       1313731     1425097            Altonah  Populated Place          UT
# 2       1313835     1425202             Atwood  Populated Place          UT
# 3       1314060     1425433             Benson  Populated Place          UT
# 4       1314332     1425709         Black Rock  Populated Place          UT
# ..          ...         ...                ...              ...         ...
# 537     1557320     1681817            Portage  Populated Place          UT
# 538     1574708     1699809        Rush Valley  Populated Place          UT
# 539     1715141     1852443             Garden  Populated Place          UT
# 540     1727991     1867579          Millcreek  Populated Place          UT
# 541     2268987     2797924  Emigration Canyon  Populated Place          UT
#
#      STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS PRIM_LONG_DMS  \
# 0               49      Beaver             1.0         381530N      1124738W
# 1               49    Duchesne            13.0         402405N      1101738W
# 2               49   Salt Lake            35.0         403758N      1115354W
# 3               49       Cache             5.0         414715N      1115549W
# 4               49     Millard            27.0         384256N      1125804W
# ..             ...         ...             ...             ...           ...
# 537             49   Box Elder             3.0         415832N      1121226W
# 538             49      Tooele            45.0         402147N      1122702W
# 539             49        Rich            33.0         415321N      1112309W
# 540             49   Salt Lake            35.0         404113N      1115232W
# 541             49   Salt Lake            35.0         404612N      1114535W
#
#      ...  SOURCE_LONG_DMS  SOURCE_LAT_DEC SOURCE_LONG_DEC ELEV_IN_M  \
# 0    ...              NaN             NaN             NaN    1685.0
# 1    ...              NaN             NaN             NaN    2034.0
# 2    ...              NaN             NaN             NaN    1323.0
# 3    ...              NaN             NaN             NaN    1350.0
# 4    ...              NaN             NaN             NaN    1480.0
# ..   ...              ...             ...             ...       ...
# 537  ...              NaN             NaN             NaN    1331.0
# 538  ...              NaN             NaN             NaN    1537.0
# 539  ...              NaN             NaN             NaN    1830.0
# 540  ...              NaN             NaN             NaN    1306.0
# 541  ...              NaN             NaN             NaN    1639.0
#
#      ELEV_IN_FT              MAP_NAME  DATE_CREATED  DATE_EDITED  \
# 0        5528.0            Adamsville    12/31/1979          NaN
# 1        6673.0               Altonah    12/31/1979          NaN
# 2        4340.0  Salt Lake City South    12/31/1979          NaN
# 3        4429.0                Newton    12/31/1979   03/21/2008
# 4        4856.0            Black Rock    12/31/1979   09/23/2013
# ..          ...                   ...           ...          ...
# 537      4367.0               Portage    04/12/1996   03/21/2008
# 538      5043.0            Saint John    08/16/1996   03/21/2008
# 539      6004.0           Garden City    12/10/1999   03/21/2008
# 540      4285.0  Salt Lake City South    05/15/2000   01/11/2017
# 541      5377.0          Fort Douglas    03/04/2019          NaN
#
#                  place count
# 0           Adamsville   1.0
# 1              Altonah   1.0
# 2               Atwood   4.0
# 3               Benson   3.0
# 4           Black Rock  17.0
# ..                 ...   ...
# 537            Portage   1.0
# 538        Rush Valley  20.0
# 539             Garden   1.0
# 540          Millcreek   4.0
# 541  Emigration Canyon   5.0
#
# [542 rows x 23 columns]

# %%
#utah_df.to_excel("utah_pop_place.xlsx")

# %%
utah_map = folium.Map(location=[39, -111], zoom_start=5)

min_number = 1

sub_df = utah_df#[utah_df.count >= min_number]

lat = list(sub_df["PRIM_LAT_DEC"])
long = list(sub_df["PRIM_LONG_DEC"])
rad = list(sub_df["count"])
name = list(sub_df["FEATURE_NAME"])

for lt,ln,r,n in zip(lat,long,rad,name):
    folium.CircleMarker(location = [lt,ln],
                        popup=n,
                        tiles='Stamen Terrain',
                        radius = 1).add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4ae3d4511b9f4fcca5c7aaf393c1e19f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4ae3d4511b9f4fcca5c7aaf393c1e19f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4ae3d4511b9f4fcca5c7aaf393c1e19f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4ae3d4511b9f4fcca5c7aaf393c1e19f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%20-111.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
min_number = 1

sub_df = utah_df#[ut_usgs_df.FEATURE_COUNTS >= min_number]

county_counts = pd.DataFrame(sub_df['COUNTY_NAME'].value_counts().reset_index())
county_counts.columns = ['county_name', 'loc_count']
total_count = []
for county in county_counts.county_name.tolist():
    #sub_df = ut_usgs_df[ut_usgs_df.COUNTY_NAME == county]
    total_count.append(sub_df[sub_df.COUNTY_NAME == county]['count'].sum())

county_counts['total_count'] = total_count

county_counts
# Out:
#    county_name  loc_count  total_count
# 0    Salt Lake        114       8426.0
# 1        Davis         51        671.0
# 2        Weber         40       1897.0
# 3         Utah         37       1399.0
# 4    Box Elder         24        715.0
# 5   Washington         23       2345.0
# 6        Cache         23        790.0
# 7      Millard         21        203.0
# 8       Carbon         19        429.0
# 9       Tooele         18        405.0
# 10     Sanpete         15        265.0
# 11      Uintah         14        220.0
# 12      Sevier         13        244.0
# 13      Summit         12        596.0
# 14        Juab         11        161.0
# 15       Emery         10        435.0
# 16      Beaver         10        147.0
# 17     Wasatch          9        150.0
# 18    Garfield          9         67.0
# 19       Grand          9         82.0
# 20    San Juan          9        189.0
# 21    Duchesne          9         98.0
# 22        Iron          9        430.0
# 23       Wayne          8        437.0
# 24        Kane          7        236.0
# 25      Morgan          6         33.0
# 26        Rich          6         34.0
# 27       Piute          5        107.0
# 28     Daggett          1         50.0

# %%
sub_df[sub_df.COUNTY_NAME == 'Washington']
# Out:
#      Unnamed: 0  FEATURE_ID  FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 35      1329057     1440940    Enterprise  Populated Place          UT
# 71      1317520     1428951     Hurricane  Populated Place          UT
# 80      1317952     1429398      LaVerkin  Populated Place          UT
# 120     1320458     1431946     Rockville  Populated Place          UT
# 122     1320743     1432234   Santa Clara  Populated Place          UT
# 126     1321368     1432867    Springdale  Populated Place          UT
# 142     1322381     1433898        Virgin  Populated Place          UT
# 167     1325659     1437504   Bloomington  Populated Place          UT
# 191     1325725     1437570       Grafton  Populated Place          UT
# 194     1325731     1437576       Gunlock  Populated Place          UT
# 196     1325738     1437583    Harrisburg  Populated Place          UT
# 223     1325791     1437636     Middleton  Populated Place          UT
# 237     1325839     1437684    Shunesburg  Populated Place          UT
# 273     1327753     1439624       Central  Populated Place          UT
# 311     1330585     1442480         Leeds  Populated Place          UT
# 336     1331902     1443808   New Harmony  Populated Place          UT
# 355     1332498     1444412   Pine Valley  Populated Place          UT
# 356     1332520     1444434       Pintura  Populated Place          UT
# 377     1333679     1445602   Silver Reef  Populated Place          UT
# 388     1334722     1446655   Toquerville  Populated Place          UT
# 401     1335081     1447019    Washington  Populated Place          UT
# 415     1338109     1450387       Hildale  Populated Place          UT
# 531     1342412     1455098  Saint George  Populated Place          UT
#
#      STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS PRIM_LONG_DMS  \
# 35              49  Washington            53.0         373425N      1134309W
# 71              49  Washington            53.0         371031N      1131724W
# 80              49  Washington            53.0         371204N      1131611W
# 120             49  Washington            53.0         370940N      1130218W
# 122             49  Washington            53.0         370759N      1133915W
# 126             49  Washington            53.0         371120N      1125955W
# 142             49  Washington            53.0         371230N      1131118W
# 167             49  Washington            53.0         370248N      1133622W
# 191             49  Washington            53.0         371002N      1130448W
# 194             49  Washington            53.0         371710N      1134548W
# 196             49  Washington            53.0         371221N      1132340W
# 223             49  Washington            53.0         370715N      1133227W
# 237             49  Washington            53.0         370929N      1125840W
# 273             49  Washington            53.0         372500N      1133728W
# 311             49  Washington            53.0         371419N      1132133W
# 336             49  Washington            53.0         372846N      1131835W
# 355             49  Washington            53.0         372328N      1133051W
# 356             49  Washington            53.0         372027N      1131627W
# 377             49  Washington            53.0         371510N      1132204W
# 388             49  Washington            53.0         371512N      1131705W
# 401             49  Washington            53.0         370750N      1133030W
# 415             49  Washington            53.0         370013N      1125801W
# 531             49  Washington            53.0         370615N      1133503W
#
#      ...  SOURCE_LONG_DMS  SOURCE_LAT_DEC SOURCE_LONG_DEC ELEV_IN_M  \
# 35   ...              NaN             NaN             NaN    1620.0
# 71   ...              NaN             NaN             NaN     988.0
# 80   ...              NaN             NaN             NaN     973.0
# 120  ...              NaN             NaN             NaN    1142.0
# 122  ...              NaN             NaN             NaN     841.0
# 126  ...              NaN             NaN             NaN    1191.0
# 142  ...              NaN             NaN             NaN    1102.0
# 167  ...              NaN             NaN             NaN     771.0
# 191  ...              NaN             NaN             NaN    1119.0
# 194  ...              NaN             NaN             NaN    1112.0
# 196  ...              NaN             NaN             NaN     916.0
# 223  ...              NaN             NaN             NaN     871.0
# 237  ...              NaN             NaN             NaN    1213.0
# 273  ...              NaN             NaN             NaN    1598.0
# 311  ...              NaN             NaN             NaN    1061.0
# 336  ...              NaN             NaN             NaN    1619.0
# 355  ...              NaN             NaN             NaN    1992.0
# 356  ...              NaN             NaN             NaN    1246.0
# 377  ...              NaN             NaN             NaN    1155.0
# 388  ...              NaN             NaN             NaN    1031.0
# 401  ...              NaN             NaN             NaN     851.0
# 415  ...              NaN             NaN             NaN    1537.0
# 531  ...              NaN             NaN             NaN     822.0
#
#      ELEV_IN_FT             MAP_NAME  DATE_CREATED  DATE_EDITED         place  \
# 35       5315.0           Enterprise    12/31/1979   03/21/2008    Enterprise
# 71       3241.0            Hurricane    12/31/1979   03/21/2008     Hurricane
# 80       3192.0            Hurricane    12/31/1979   03/21/2008      LaVerkin
# 120      3747.0      Springdale West    12/31/1979   03/21/2008     Rockville
# 122      2759.0          Santa Clara    12/31/1979   03/21/2008   Santa Clara
# 126      3907.0      Springdale East    12/31/1979   03/21/2008    Springdale
# 142      3615.0               Virgin    12/31/1979   03/21/2008        Virgin
# 167      2529.0         Saint George    12/31/1979          NaN   Bloomington
# 191      3671.0      Springdale West    12/31/1979          NaN       Grafton
# 194      3648.0              Gunlock    12/31/1979          NaN       Gunlock
# 196      3005.0  Harrisburg Junction    12/31/1979   02/15/2006    Harrisburg
# 223      2858.0         Saint George    12/31/1979          NaN     Middleton
# 237      3980.0      Springdale East    12/31/1979          NaN    Shunesburg
# 273      5243.0         Central East    12/31/1979   01/29/2011       Central
# 311      3481.0            Hurricane    12/31/1979   03/21/2008         Leeds
# 336      5312.0          New Harmony    12/31/1979   03/21/2008   New Harmony
# 355      6535.0         Central East    12/31/1979   01/29/2011   Pine Valley
# 356      4088.0              Pintura    12/31/1979          NaN       Pintura
# 377      3789.0              Pintura    12/31/1979          NaN   Silver Reef
# 388      3383.0              Pintura    12/31/1979   03/21/2008   Toquerville
# 401      2792.0           Washington    12/31/1979   03/21/2008    Washington
# 415      5043.0              Hildale    02/25/1989   03/21/2008       Hildale
# 531      2697.0         Saint George    12/31/1979   03/21/2008  Saint George
#
#       count
# 35      4.0
# 71     41.0
# 80      1.0
# 120    51.0
# 122   227.0
# 126    16.0
# 142    26.0
# 167    12.0
# 191     7.0
# 194    14.0
# 196    22.0
# 223     1.0
# 237     4.0
# 273     1.0
# 311     3.0
# 336     7.0
# 355    29.0
# 356     8.0
# 377     8.0
# 388     6.0
# 401  1230.0
# 415     2.0
# 531   625.0
#
# [23 rows x 23 columns]

# %%
#Import Libraries
import geopandas as gpd
import pandas as pd
import numpy as np
import folium
from folium.features import GeoJsonTooltip

#Read the geoJSON file using geopandas
geojson = gpd.read_file('georef-united-states-of-america-county.geojson')
geojson=geojson[geojson['ste_name'] == "Utah"]

ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

folium.Choropleth(geo_data=geojson).add_to(ut_county_map)

df_final = geojson.merge(county_counts, left_on="coty_name", right_on="county_name", how="outer") 
df_final = df_final[~df_final['geometry'].isna()]
df_final
# Out:
#    coty_code coty_gnis_code     coty_name_long ste_name coty_type  year  \
# 0      49037       01448032    San Juan County     Utah    county  2020
# 1      49043       01448035      Summit County     Utah    county  2020
# 2      49041       01448034      Sevier County     Utah    county  2020
# 3      49051       01448039     Wasatch County     Utah    county  2020
# 4      49021       01448025        Iron County     Utah    county  2020
# 5      49017       01448023    Garfield County     Utah    county  2020
# 6      49011       01448020       Davis County     Utah    county  2020
# 7      49009       01448019     Daggett County     Utah    county  2020
# 8      49029       01448028      Morgan County     Utah    county  2020
# 9      49035       01448031   Salt Lake County     Utah    county  2020
# 10     49057       01448042       Weber County     Utah    county  2020
# 11     49013       01448021    Duchesne County     Utah    county  2020
# 12     49031       01448029       Piute County     Utah    county  2020
# 13     49033       01448030        Rich County     Utah    county  2020
# 14     49039       01448033     Sanpete County     Utah    county  2020
# 15     49023       01455158        Juab County     Utah    county  2020
# 16     49005       01448017       Cache County     Utah    county  2020
# 17     49007       01448018      Carbon County     Utah    county  2020
# 18     49053       01448040  Washington County     Utah    county  2020
# 19     49003       01455966   Box Elder County     Utah    county  2020
# 20     49015       01448022       Emery County     Utah    county  2020
# 21     49001       01448015      Beaver County     Utah    county  2020
# 22     49019       01448024       Grand County     Utah    county  2020
# 23     49047       01448037      Uintah County     Utah    county  2020
# 24     49027       01448027     Millard County     Utah    county  2020
# 25     49045       01448036      Tooele County     Utah    county  2020
# 26     49055       01448041       Wayne County     Utah    county  2020
# 27     49049       01448038        Utah County     Utah    county  2020
# 28     49025       01448026        Kane County     Utah    county  2020
#
#    coty_area_code ste_code coty_fp_code   coty_name  \
# 0             USA       49          037    San Juan
# 1             USA       49          043      Summit
# 2             USA       49          041      Sevier
# 3             USA       49          051     Wasatch
# 4             USA       49          021        Iron
# 5             USA       49          017    Garfield
# 6             USA       49          011       Davis
# 7             USA       49          009     Daggett
# 8             USA       49          029      Morgan
# 9             USA       49          035   Salt Lake
# 10            USA       49          057       Weber
# 11            USA       49          013    Duchesne
# 12            USA       49          031       Piute
# 13            USA       49          033        Rich
# 14            USA       49          039     Sanpete
# 15            USA       49          023        Juab
# 16            USA       49          005       Cache
# 17            USA       49          007      Carbon
# 18            USA       49          053  Washington
# 19            USA       49          003   Box Elder
# 20            USA       49          015       Emery
# 21            USA       49          001      Beaver
# 22            USA       49          019       Grand
# 23            USA       49          047      Uintah
# 24            USA       49          027     Millard
# 25            USA       49          045      Tooele
# 26            USA       49          055       Wayne
# 27            USA       49          049        Utah
# 28            USA       49          025        Kane
#
#                                              geometry county_name  loc_count  \
# 0   POLYGON ((-109.92799 38.15188, -109.92719 38.1...    San Juan          9
# 1   POLYGON ((-111.26497 41.14404, -111.27467 41.1...      Summit         12
# 2   POLYGON ((-112.51850 38.51041, -112.44870 38.5...      Sevier         13
# 3   POLYGON ((-110.89166 39.89965, -110.89197 40.0...     Wasatch          9
# 4   POLYGON ((-114.04998 38.14876, -114.05004 38.0...        Iron          9
# 5   POLYGON ((-112.47868 38.14742, -112.47873 38.0...    Garfield          9
# 6   POLYGON ((-112.26022 40.76909, -112.14827 40.8...       Davis         51
# 7   POLYGON ((-109.04894 40.66260, -109.04909 40.7...     Daggett          1
# 8   POLYGON ((-111.42073 41.36131, -111.42401 41.3...      Morgan          6
# 9   POLYGON ((-111.59388 40.57706, -111.59070 40.5...   Salt Lake        114
# 10  POLYGON ((-111.51084 41.42310, -111.51735 41.4...       Weber         40
# 11  POLYGON ((-109.97640 40.80969, -109.98805 40.8...    Duchesne          9
# 12  POLYGON ((-112.44421 38.15000, -112.34472 38.1...       Piute          5
# 13  POLYGON ((-111.50781 41.99955, -111.50879 41.9...        Rich          6
# 14  POLYGON ((-111.64194 39.81287, -111.64206 39.7...     Sanpete         15
# 15  POLYGON ((-112.17980 40.01166, -112.18686 40.0...        Juab         11
# 16  POLYGON ((-111.50781 41.99955, -111.54244 41.9...       Cache         23
# 17  POLYGON ((-109.97681 39.80623, -110.06291 39.8...      Carbon         19
# 18  POLYGON ((-112.89919 37.00038, -112.89917 37.0...  Washington         23
# 19  POLYGON ((-112.15918 41.99838, -112.17315 42.0...   Box Elder         24
# 20  POLYGON ((-110.02540 38.49998, -110.04082 38.5...       Emery         10
# 21  POLYGON ((-114.04998 38.14876, -113.90718 38.1...      Beaver         10
# 22  POLYGON ((-110.02396 39.46927, -110.02412 39.4...       Grand          9
# 23  POLYGON ((-109.04894 40.66260, -109.12348 40.6...      Uintah         14
# 24  POLYGON ((-112.51539 38.57284, -112.51239 38.5...     Millard         21
# 25  POLYGON ((-112.17286 40.46706, -112.17185 40.4...      Tooele         18
# 26  POLYGON ((-111.30567 38.51017, -111.37573 38.5...       Wayne          8
# 27  POLYGON ((-112.17286 40.46706, -112.19027 40.4...        Utah         37
# 28  POLYGON ((-112.53857 37.00076, -112.49004 37.0...        Kane          7
#
#     total_count
# 0         189.0
# 1         596.0
# 2         244.0
# 3         150.0
# 4         430.0
# 5          67.0
# 6         671.0
# 7          50.0
# 8          33.0
# 9        8426.0
# 10       1897.0
# 11         98.0
# 12        107.0
# 13         34.0
# 14        265.0
# 15        161.0
# 16        790.0
# 17        429.0
# 18       2345.0
# 19        715.0
# 20        435.0
# 21        147.0
# 22         82.0
# 23        220.0
# 24        203.0
# 25        405.0
# 26        437.0
# 27       1399.0
# 28        236.0

# %%
ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

map_variable = 'total_count' #possible variables: 'loc_count' & 'total_count'

folium.Choropleth(
            geo_data=geojson,
            data=df_final,
            columns=['coty_code', map_variable],  #Here we tell folium to get the county fips and plot new_cases_7days metric for each county
            key_on='feature.properties.coty_code', #Here we grab the geometries/county boundaries from the geojson file using the key 'coty_code' which is the same as county fips
            #threshold_scale=(df_final[map_variable].quantile((0, 0.2, 0.4, 0.6, 0.8, 1))).tolist(), #we can create our own custom scale if we like.
            fill_color='YlOrRd',
            nan_fill_color="White", #Use white color if there is no data available for the county
            fill_opacity=0.7,
            line_opacity=0.2,
            legend_name='', #title of the legend
            highlight=True,
            line_color='black').add_to(ut_county_map)

ut_county_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-94433c893e26> in <module>
# ----> 1 ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)
#       2
#       3 map_variable = 'total_count' #possible variables: 'loc_count' & 'total_count'
#       4
#       5 folium.Choropleth(
#
# NameError: name 'folium' is not defined

# %% [markdown]
# ## COUNTY SEARCH

# %%
year_begin = 1928 #UHQ first year is 1928
year_end = 2021 #UHQ end year is 2021

#creating string containing all UHQ texts
df2 = df[(df['text'].notna()) & (df['year'] >= year_begin) & (df['year'] <= year_end)].reset_index()

full_uhq_texts = ' '.join([str(elem) for elem in df2.text.tolist()])

# %%
counties = df_final.coty_name_long.tolist()

county_count = []
for c in counties:
    county_count.append(full_uhq_texts.count(c))

df_final['raw_counts'] = county_count

# %%
df_final
# Out:
#    coty_code coty_gnis_code     coty_name_long ste_name coty_type  year  \
# 0      49037       01448032    San Juan County     Utah    county  2020
# 1      49043       01448035      Summit County     Utah    county  2020
# 2      49041       01448034      Sevier County     Utah    county  2020
# 3      49051       01448039     Wasatch County     Utah    county  2020
# 4      49021       01448025        Iron County     Utah    county  2020
# 5      49017       01448023    Garfield County     Utah    county  2020
# 6      49011       01448020       Davis County     Utah    county  2020
# 7      49009       01448019     Daggett County     Utah    county  2020
# 8      49029       01448028      Morgan County     Utah    county  2020
# 9      49035       01448031   Salt Lake County     Utah    county  2020
# 10     49057       01448042       Weber County     Utah    county  2020
# 11     49013       01448021    Duchesne County     Utah    county  2020
# 12     49031       01448029       Piute County     Utah    county  2020
# 13     49033       01448030        Rich County     Utah    county  2020
# 14     49039       01448033     Sanpete County     Utah    county  2020
# 15     49023       01455158        Juab County     Utah    county  2020
# 16     49005       01448017       Cache County     Utah    county  2020
# 17     49007       01448018      Carbon County     Utah    county  2020
# 18     49053       01448040  Washington County     Utah    county  2020
# 19     49003       01455966   Box Elder County     Utah    county  2020
# 20     49015       01448022       Emery County     Utah    county  2020
# 21     49001       01448015      Beaver County     Utah    county  2020
# 22     49019       01448024       Grand County     Utah    county  2020
# 23     49047       01448037      Uintah County     Utah    county  2020
# 24     49027       01448027     Millard County     Utah    county  2020
# 25     49045       01448036      Tooele County     Utah    county  2020
# 26     49055       01448041       Wayne County     Utah    county  2020
# 27     49049       01448038        Utah County     Utah    county  2020
# 28     49025       01448026        Kane County     Utah    county  2020
#
#    coty_area_code ste_code coty_fp_code   coty_name  \
# 0             USA       49          037    San Juan
# 1             USA       49          043      Summit
# 2             USA       49          041      Sevier
# 3             USA       49          051     Wasatch
# 4             USA       49          021        Iron
# 5             USA       49          017    Garfield
# 6             USA       49          011       Davis
# 7             USA       49          009     Daggett
# 8             USA       49          029      Morgan
# 9             USA       49          035   Salt Lake
# 10            USA       49          057       Weber
# 11            USA       49          013    Duchesne
# 12            USA       49          031       Piute
# 13            USA       49          033        Rich
# 14            USA       49          039     Sanpete
# 15            USA       49          023        Juab
# 16            USA       49          005       Cache
# 17            USA       49          007      Carbon
# 18            USA       49          053  Washington
# 19            USA       49          003   Box Elder
# 20            USA       49          015       Emery
# 21            USA       49          001      Beaver
# 22            USA       49          019       Grand
# 23            USA       49          047      Uintah
# 24            USA       49          027     Millard
# 25            USA       49          045      Tooele
# 26            USA       49          055       Wayne
# 27            USA       49          049        Utah
# 28            USA       49          025        Kane
#
#                                              geometry county_name  loc_count  \
# 0   POLYGON ((-109.92799 38.15188, -109.92719 38.1...    San Juan          9
# 1   POLYGON ((-111.26497 41.14404, -111.27467 41.1...      Summit         12
# 2   POLYGON ((-112.51850 38.51041, -112.44870 38.5...      Sevier         13
# 3   POLYGON ((-110.89166 39.89965, -110.89197 40.0...     Wasatch          9
# 4   POLYGON ((-114.04998 38.14876, -114.05004 38.0...        Iron          9
# 5   POLYGON ((-112.47868 38.14742, -112.47873 38.0...    Garfield          9
# 6   POLYGON ((-112.26022 40.76909, -112.14827 40.8...       Davis         51
# 7   POLYGON ((-109.04894 40.66260, -109.04909 40.7...     Daggett          1
# 8   POLYGON ((-111.42073 41.36131, -111.42401 41.3...      Morgan          6
# 9   POLYGON ((-111.59388 40.57706, -111.59070 40.5...   Salt Lake        114
# 10  POLYGON ((-111.51084 41.42310, -111.51735 41.4...       Weber         40
# 11  POLYGON ((-109.97640 40.80969, -109.98805 40.8...    Duchesne          9
# 12  POLYGON ((-112.44421 38.15000, -112.34472 38.1...       Piute          5
# 13  POLYGON ((-111.50781 41.99955, -111.50879 41.9...        Rich          6
# 14  POLYGON ((-111.64194 39.81287, -111.64206 39.7...     Sanpete         15
# 15  POLYGON ((-112.17980 40.01166, -112.18686 40.0...        Juab         11
# 16  POLYGON ((-111.50781 41.99955, -111.54244 41.9...       Cache         23
# 17  POLYGON ((-109.97681 39.80623, -110.06291 39.8...      Carbon         19
# 18  POLYGON ((-112.89919 37.00038, -112.89917 37.0...  Washington         23
# 19  POLYGON ((-112.15918 41.99838, -112.17315 42.0...   Box Elder         24
# 20  POLYGON ((-110.02540 38.49998, -110.04082 38.5...       Emery         10
# 21  POLYGON ((-114.04998 38.14876, -113.90718 38.1...      Beaver         10
# 22  POLYGON ((-110.02396 39.46927, -110.02412 39.4...       Grand          9
# 23  POLYGON ((-109.04894 40.66260, -109.12348 40.6...      Uintah         14
# 24  POLYGON ((-112.51539 38.57284, -112.51239 38.5...     Millard         21
# 25  POLYGON ((-112.17286 40.46706, -112.17185 40.4...      Tooele         18
# 26  POLYGON ((-111.30567 38.51017, -111.37573 38.5...       Wayne          8
# 27  POLYGON ((-112.17286 40.46706, -112.19027 40.4...        Utah         37
# 28  POLYGON ((-112.53857 37.00076, -112.49004 37.0...        Kane          7
#
#     total_count  raw_counts
# 0         189.0         165
# 1         596.0          72
# 2         244.0          70
# 3         150.0          73
# 4         430.0         184
# 5          67.0          12
# 6         671.0         143
# 7          50.0          55
# 8          33.0           8
# 9        8426.0         313
# 10       1897.0         178
# 11         98.0          30
# 12        107.0          17
# 13         34.0          17
# 14        265.0         143
# 15        161.0          37
# 16        790.0         114
# 17        429.0         474
# 18       2345.0         147
# 19        715.0         107
# 20        435.0          96
# 21        147.0          44
# 22         82.0          33
# 23        220.0          49
# 24        203.0         154
# 25        405.0         101
# 26        437.0          40
# 27       1399.0         181
# 28        236.0          90

# %%
ut_county_map = folium.Map(location=[39.5, -111], zoom_start=7)

map_variable = 'raw_counts' #possible variables: 'loc_count' & 'total_count'

folium.Choropleth(
            geo_data=geojson,
            data=df_final,
            columns=['coty_code', map_variable],  #Here we tell folium to get the county fips and plot new_cases_7days metric for each county
            key_on='feature.properties.coty_code', #Here we grab the geometries/county boundaries from the geojson file using the key 'coty_code' which is the same as county fips
            #threshold_scale=(df_final[map_variable].quantile((0, 0.2, 0.4, 0.6, 0.8, 1))).tolist(), #we can create our own custom scale if we like.
            fill_color='YlOrRd',
            nan_fill_color="White", #Use white color if there is no data available for the county
            fill_opacity=0.7,
            line_opacity=0.2,
            legend_name='', #title of the legend
            highlight=True,
            line_color='black').add_to(ut_county_map)

ut_county_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f4ab0800de1c4bf1a61b06974da2bb1a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f4ab0800de1c4bf1a61b06974da2bb1a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f4ab0800de1c4bf1a61b06974da2bb1a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f4ab0800de1c4bf1a61b06974da2bb1a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
